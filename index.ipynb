# %% [markdown]
# # Applying Gradient Descent Lab

# %% [markdown]
# ### Introduction

# %% [markdown]
# In this lab, we'll put our knowledge about data science to the test. We will have access to functions in the [error](https://github.com/learn-co-curriculum/applying-gradient-descent-lab/blob/master/error.py), [graph](https://github.com/learn-co-curriculum/applying-gradient-descent-lab/blob/master/graph.py) and [linear equations](https://github.com/learn-co-curriculum/applying-gradient-descent-lab/blob/master/linear_equations.py) libraries that we previously wrote.
#
# This is our task: We are an employee for *Good Lion Studios*. For *Good Lion*, our job is first to gather, explore, and format our data so that we can build a regression line of this data. Then we will work through various attempts of building out these regression lines. By the end of this lab, we should have a working version that we can proudly show to our manager.

# %% [markdown]
# ### Learning Objectives

# %% [markdown]
# * Review how to use built-in functions, like filter and map, to clean data
# * Evaluate the quality of regression lines using Residual Sum of Squares (RSS)
# * Review how RSS changes with varying values of the slope and y-intercept of a regression line
# * Implement gradient descent to find a "best fit" regression line
#
# This lesson is an opportunity to review the concepts explained in our introduction to machine learning section and practice what we recently learned about gradient descent to find an optimal regression line.
#
# > ****Use the round method****: For many of the methods, we round down the return value to two decimal places. We can do so by using the **round** function, as in **round(12.1212, 2)** to round 12.1212 to 12.12. We did this to allow for slight differences between our results and expectations. So when we see our data differing from the expectation, check if using the **round** function helps.

# %% [markdown]
# ### Determining Quality

# %% [markdown]
# #### Retrieve the data
#
# First, let's get some movies from the FiveThirtyEight dataset [provided here](https://raw.githubusercontent.com/fivethirtyeight/data/master/bechdel/movies.csv).  The code below parses this data from the csv file and saves it to the `movies` variable as a list of dictionaries.

# %%
import pandas

def parse_file(fileName):
    movies_df = pandas.read_csv(fileName)
    return movies_df.to_dict('records')

movies = parse_file('https://raw.githubusercontent.com/fivethirtyeight/data/master/bechdel/movies.csv')

# %%
type(movies) # list
len(movies) # 1794
# Out:
# 1794

# %% [markdown]
# As you can see, this list is full of 1794 dictionaries, each one representing a movie.

# %% [markdown]
# #### Explore the data
#
#
# Let's take a look at that first movie in the dataset.

# %%
movies[0]
# Out:
# {'year': 2013,
#  'imdb': 'tt1711425',
#  'title': '21 &amp; Over',
#  'test': 'notalk',
#  'clean_test': 'notalk',
#  'binary': 'FAIL',
#  'budget': 13000000,
#  'domgross': 25682380.0,
#  'intgross': 42195766.0,
#  'code': '2013FAIL',
#  'budget_2013$': 13000000,
#  'domgross_2013$': 25682380.0,
#  'intgross_2013$': 42195766.0,
#  'period code': 1.0,
#  'decade code': 1.0}

# %% [markdown]
# Here we can see the data available for each movie. The information most relevant for our task is:
#
# 1. `budget_2013$` is the budget adjusted for inflation in 2013 dollars
# 2. `domgross_2013$` is the domestic revenue adjusted for inflation in 2013 dollars
# 3. `intgross_2013$` is the international revenue adjusted for inflation in 2013 dollars

# %% [markdown]
# ### Cleaning our data

# %% [markdown]
# #### 1. Handle missing data
#
# Now, let's look at the values associated with these attributes.  The first movie looks good since it has nice data for each of these attributes. Unfortunately, the data for some other movies might not be so fun to play with. Let's remove the movies whose `domgross_2013` points to values of `nan`, which stands for "not a number". This data is missing.  There are only a few pieces of missing data here, so we can safely remove these movies without causing too much damage.

# %%
import math
list(filter(lambda movie: math.isnan(movie['domgross_2013$']), movies))
# Out:
# [{'year': 2013,
#   'imdb': 'tt2005374',
#   'title': 'The Frozen Ground',
#   'test': 'nowomen-disagree',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 19200000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2013FAIL',
#   'budget_2013$': 19200000,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2011,
#   'imdb': 'tt1422136',
#   'title': 'A Lonely Place to Die',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 4000000,
#   'domgross': nan,
#   'intgross': 442550.0,
#   'code': '2011PASS',
#   'budget_2013$': 4142763,
#   'domgross_2013$': nan,
#   'intgross_2013$': 458345.0,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2011,
#   'imdb': 'tt1701990',
#   'title': 'Detention',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 10000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2011PASS',
#   'budget_2013$': 10356908,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2010,
#   'imdb': 'tt1216520',
#   'title': 'Womb',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 13000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2010PASS',
#   'budget_2013$': 13887014,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2009,
#   'imdb': 'tt1024744',
#   'title': 'I Come with the Rain',
#   'test': 'nowomen',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 18000000,
#   'domgross': 0.0,
#   'intgross': 627422.0,
#   'code': '2009FAIL',
#   'budget_2013$': 19543169,
#   'domgross_2013$': nan,
#   'intgross_2013$': 681212.0,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2009,
#   'imdb': 'tt1068678',
#   'title': 'Veronika Decides to Die',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 9000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2009PASS',
#   'budget_2013$': 9771584,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2009,
#   'imdb': 'tt0448182',
#   'title': 'Yesterday Was a Lie',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 200000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2009PASS',
#   'budget_2013$': 217146,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2008,
#   'imdb': 'tt0489018',
#   'title': 'Day of the Dead',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 18000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2008PASS',
#   'budget_2013$': 19480614,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2008,
#   'imdb': 'tt0942903',
#   'title': 'Stargate: The Ark of Truth',
#   'test': 'dubious-disagree',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 7000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2008FAIL',
#   'budget_2013$': 7575794,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2008,
#   'imdb': 'tt0882978',
#   'title': 'Three Kingdoms: Resurrection of the Dragon',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 20000000,
#   'domgross': nan,
#   'intgross': 22139590.0,
#   'code': '2008FAIL',
#   'budget_2013$': 21645126,
#   'domgross_2013$': nan,
#   'intgross_2013$': 23960711.0,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2007,
#   'imdb': 'tt1038988',
#   'title': '[Rec]',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 2100000,
#   'domgross': nan,
#   'intgross': 27117954.0,
#   'code': '2007PASS',
#   'budget_2013$': 2359441,
#   'domgross_2013$': nan,
#   'intgross_2013$': 30468201.0,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2007,
#   'imdb': 'tt0756683',
#   'title': 'The Man from Earth',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 200000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2007FAIL',
#   'budget_2013$': 224709,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2007,
#   'imdb': 'tt0496436',
#   'title': 'White Noise 2: The Light',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 10000000,
#   'domgross': nan,
#   'intgross': 8243567.0,
#   'code': '2007FAIL',
#   'budget_2013$': 11235435,
#   'domgross_2013$': nan,
#   'intgross_2013$': 9262006.0,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2006,
#   'imdb': 'tt0416496',
#   'title': 'Bandidas',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 35000000,
#   'domgross': nan,
#   'intgross': 18400000.0,
#   'code': '2006PASS',
#   'budget_2013$': 40452872,
#   'domgross_2013$': nan,
#   'intgross_2013$': 21266653.0,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2006,
#   'imdb': 'tt0490166',
#   'title': 'London To Brighton',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 825000,
#   'domgross': nan,
#   'intgross': 610776.0,
#   'code': '2006PASS',
#   'budget_2013$': 953532,
#   'domgross_2013$': nan,
#   'intgross_2013$': 705933.0,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 1985,
#   'imdb': 'tt0088993',
#   'title': 'Day of the Dead',
#   'test': 'nowomen',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 18000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '1985FAIL',
#   'budget_2013$': 38971004,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': nan,
#   'decade code': nan},
#  {'year': 1985,
#   'imdb': 'tt0091578',
#   'title': 'My Beautiful Laundrette',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 400000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '1985FAIL',
#   'budget_2013$': 866022,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': nan,
#   'decade code': nan},
#  {'year': 1972,
#   'imdb': 'tt0068156',
#   'title': '1776',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 4000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '1972FAIL',
#   'budget_2013$': 22288557,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': nan,
#   'decade code': nan}]

# %% [markdown]
# Write a function called `remove_movies_missing_data` that returns the subset of movies that don't have `nan`.
#
# > To do so, you can import the math library and make use of the `math.isnan` method.  More information about this method can be [found here](https://stackoverflow.com/questions/944700/how-can-i-check-for-nan-in-python).

# %%
import math

def remove_movies_missing_data(movies):
    no_data_missing = movies[:]
    return list(filter(lambda movie: not math.isnan(movie['domgross_2013$']), no_data_missing))

# %%
parsed_movies = remove_movies_missing_data(movies) or []

# %% [markdown]
# After writing the `remove_movies_missing_data` function, notice that we have reduced the number of movies down from 1794 to 1776 movies.

# %%
len(parsed_movies) # 1776
# Out:
# 1776

# %% [markdown]
# Also, we can see that no movies with a `domgross_2013` value of `nan` are included.

# %%
list(filter(lambda movie: math.isnan(movie['domgross_2013$']),parsed_movies)) # []
# Out:
# []

# %% [markdown]
# #### 2. Changing the scale of our data
#
# Currently, our data has some very large numbers:

# %%
movies[0]['budget']
# Out:
# 13000000

# %% [markdown]
# It takes some time to figure out if the number above is 13 million.  It would be frustrating to count all of the zeros whenever we come across another set of movie budgets and revenues.
#
# To make things simpler, let's divide both our budget and revenue numbers for each movie by 1 million. It will make some of our future calculations easier to interpret. The attributes that we can scale down are `budget`, `budget_2013$`, `domgross`, `domgross_2013$`, `intgross`, and `intgross_2013$`.
#
# Write a function called `scale_down_movie` that can take an element from our movies list and return that same movie but with the `budget`, `budget_2013$`, `domgross`, `domgross_2013$`, `intgross`, and `intgross_2013$` numbers all divided by 1 million and rounded to two decimal places.

# %%
def scale_down_movie(movie):
    scaled_movies = movies[:]
    for movie in scaled_moves:
        movie['budget'] = round(movie['budget']/1000000, 2)
        movie['budget'] = round(movie['budget']/1000000, 2)
    return list(map(lambda movie: {k:round(v/1000000,2) for k,v in movie.items() if k in ['budget', 'budget_2013$','domgross','domgross_2013$']}, scaled_movies))
    pass

# %%
movies[0]
# Out:
# {'year': 2013,
#  'imdb': 'tt1711425',
#  'title': '21 &amp; Over',
#  'test': 'notalk',
#  'clean_test': 'notalk',
#  'binary': 'FAIL',
#  'budget': 13000000,
#  'domgross': 25682380.0,
#  'intgross': 42195766.0,
#  'code': '2013FAIL',
#  'budget_2013$': 13000000,
#  'domgross_2013$': 25682380.0,
#  'intgross_2013$': 42195766.0,
#  'period code': 1.0,
#  'decade code': 1.0}

# %%
scale_down_movie(movies[0])
# Out:
# [{'budget': 13.0,
#   'domgross': 25.68,
#   'budget_2013$': 13.0,
#   'domgross_2013$': 25.68},
#  {'budget': 45.0,
#   'domgross': 13.41,
#   'budget_2013$': 45.66,
#   'domgross_2013$': 13.61},
#  {'budget': 20.0,
#   'domgross': 53.11,
#   'budget_2013$': 20.0,
#   'domgross_2013$': 53.11},
#  {'budget': 61.0,
#   'domgross': 75.61,
#   'budget_2013$': 61.0,
#   'domgross_2013$': 75.61},
#  {'budget': 40.0,
#   'domgross': 95.02,
#   'budget_2013$': 40.0,
#   'domgross_2013$': 95.02},
#  {'budget': 225.0,
#   'domgross': 38.36,
#   'budget_2013$': 225.0,
#   'domgross_2013$': 38.36},
#  {'budget': 92.0,
#   'domgross': 67.35,
#   'budget_2013$': 92.0,
#   'domgross_2013$': 67.35},
#  {'budget': 12.0,
#   'domgross': 15.32,
#   'budget_2013$': 12.0,
#   'domgross_2013$': 15.32},
#  {'budget': 13.0,
#   'domgross': 18.01,
#   'budget_2013$': 13.0,
#   'domgross_2013$': 18.01},
#  {'budget': 130.0,
#   'domgross': 60.52,
#   'budget_2013$': 130.0,
#   'domgross_2013$': 60.52},
#  {'budget': 40.0,
#   'domgross': 148.43,
#   'budget_2013$': 40.0,
#   'domgross_2013$': 148.43},
#  {'budget': 25.0,
#   'domgross': 37.3,
#   'budget_2013$': 25.0,
#   'domgross_2013$': 37.3},
#  {'budget': 50.0,
#   'domgross': 19.45,
#   'budget_2013$': 50.0,
#   'domgross_2013$': 19.45},
#  {'budget': 18.0,
#   'domgross': 33.35,
#   'budget_2013$': 18.0,
#   'domgross_2013$': 33.35},
#  {'budget': 55.0,
#   'domgross': 107.14,
#   'budget_2013$': 55.0,
#   'domgross_2013$': 107.14},
#  {'budget': 30.0,
#   'domgross': 35.27,
#   'budget_2013$': 30.0,
#   'domgross_2013$': 35.27},
#  {'budget': 78.0,
#   'domgross': 119.64,
#   'budget_2013$': 78.0,
#   'domgross_2013$': 119.64},
#  {'budget': 76.0,
#   'domgross': 368.07,
#   'budget_2013$': 76.0,
#   'domgross_2013$': 368.07},
#  {'budget': 5.5,
#   'domgross': 24.48,
#   'budget_2013$': 5.5,
#   'domgross_2013$': 24.48},
#  {'budget': 120.0,
#   'domgross': 93.05,
#   'budget_2013$': 120.0,
#   'domgross_2013$': 93.05},
#  {'budget': 110.0,
#   'domgross': 61.74,
#   'budget_2013$': 110.0,
#   'domgross_2013$': 61.74},
#  {'budget': 100.0,
#   'domgross': 107.52,
#   'budget_2013$': 100.0,
#   'domgross_2013$': 107.52},
#  {'budget': 40.0,
#   'domgross': 57.01,
#   'budget_2013$': 40.0,
#   'domgross_2013$': 57.01},
#  {'budget': 70.0,
#   'domgross': 25.21,
#   'budget_2013$': 70.0,
#   'domgross_2013$': 25.21},
#  {'budget': 17.0,
#   'domgross': 54.24,
#   'budget_2013$': 17.0,
#   'domgross_2013$': 54.24},
#  {'budget': 160.0,
#   'domgross': 238.68,
#   'budget_2013$': 160.0,
#   'domgross_2013$': 238.68},
#  {'budget': 150.0,
#   'domgross': 393.05,
#   'budget_2013$': 150.0,
#   'domgross_2013$': 393.05},
#  {'budget': 140.0,
#   'domgross': 122.52,
#   'budget_2013$': 140.0,
#   'domgross_2013$': 122.52},
#  {'budget': 60.0,
#   'domgross': 46.0,
#   'budget_2013$': 60.0,
#   'domgross_2013$': 46.0},
#  {'budget': 30.0,
#   'domgross': 4.17,
#   'budget_2013$': 30.0,
#   'domgross_2013$': 4.17},
#  {'budget': 110.0,
#   'domgross': 271.81,
#   'budget_2013$': 110.0,
#   'domgross_2013$': 271.81},
#  {'budget': 80.0,
#   'domgross': 133.67,
#   'budget_2013$': 80.0,
#   'domgross_2013$': 133.67},
#  {'budget': 50.0,
#   'domgross': 55.7,
#   'budget_2013$': 50.0,
#   'domgross_2013$': 55.7},
#  {'budget': 23.0,
#   'domgross': 25.0,
#   'budget_2013$': 23.0,
#   'domgross_2013$': 25.0},
#  {'budget': 35.0,
#   'domgross': 134.51,
#   'budget_2013$': 35.0,
#   'domgross_2013$': 134.51},
#  {'budget': 5.0,
#   'domgross': 83.59,
#   'budget_2013$': 5.0,
#   'domgross_2013$': 83.59},
#  {'budget': 200.0,
#   'domgross': 408.99,
#   'budget_2013$': 200.0,
#   'domgross_2013$': 408.99},
#  {'budget': 195.0,
#   'domgross': 65.19,
#   'budget_2013$': 195.0,
#   'domgross_2013$': 65.19},
#  {'budget': 28.0,
#   'domgross': 28.8,
#   'budget_2013$': 28.0,
#   'domgross_2013$': 28.8},
#  {'budget': 28.0,
#   'domgross': 63.91,
#   'budget_2013$': 28.0,
#   'domgross_2013$': 63.91},
#  {'budget': 30.0,
#   'domgross': 116.63,
#   'budget_2013$': 30.0,
#   'domgross_2013$': 116.63},
#  {'budget': 2.0,
#   'domgross': 8.01,
#   'budget_2013$': 2.0,
#   'domgross_2013$': 8.01},
#  {'budget': 15.0,
#   'domgross': 71.63,
#   'budget_2013$': 15.0,
#   'domgross_2013$': 71.63},
#  {'budget': 225.0,
#   'domgross': 291.05,
#   'budget_2013$': 225.0,
#   'domgross_2013$': 291.05},
#  {'budget': 12.0,
#   'domgross': 17.48,
#   'budget_2013$': 12.0,
#   'domgross_2013$': 17.48},
#  {'budget': 75.0,
#   'domgross': 117.72,
#   'budget_2013$': 75.0,
#   'domgross_2013$': 117.72},
#  {'budget': 120.0,
#   'domgross': 89.11,
#   'budget_2013$': 120.0,
#   'domgross_2013$': 89.11},
#  {'budget': 70.0,
#   'domgross': 98.93,
#   'budget_2013$': 70.0,
#   'domgross_2013$': 98.93},
#  {'budget': 200.0,
#   'domgross': 234.77,
#   'budget_2013$': 200.0,
#   'domgross_2013$': 234.77},
#  {'budget': 190.0,
#   'domgross': 101.8,
#   'budget_2013$': 190.0,
#   'domgross_2013$': 101.8},
#  {'budget': 26.0,
#   'domgross': 49.88,
#   'budget_2013$': 26.0,
#   'domgross_2013$': 49.88},
#  {'budget': 35.0,
#   'domgross': 17.62,
#   'budget_2013$': 35.0,
#   'domgross_2013$': 17.62},
#  {'budget': 15.0,
#   'domgross': 9.18,
#   'budget_2013$': 15.0,
#   'domgross_2013$': 9.18},
#  {'budget': 90.0,
#   'domgross': 68.56,
#   'budget_2013$': 90.0,
#   'domgross_2013$': 68.56},
#  {'budget': 46.0,
#   'domgross': 61.0,
#   'budget_2013$': 46.0,
#   'domgross_2013$': 61.0},
#  {'budget': 130.0,
#   'domgross': 33.62,
#   'budget_2013$': 130.0,
#   'domgross_2013$': 33.62},
#  {'budget': 84.0,
#   'domgross': 53.26,
#   'budget_2013$': 84.0,
#   'domgross_2013$': 53.26},
#  {'budget': 38.0,
#   'domgross': 42.03,
#   'budget_2013$': 38.0,
#   'domgross_2013$': 42.03},
#  {'budget': 30.0,
#   'domgross': 19.32,
#   'budget_2013$': 30.0,
#   'domgross_2013$': 19.32},
#  {'budget': 38.0,
#   'domgross': 26.95,
#   'budget_2013$': 38.0,
#   'domgross_2013$': 26.95},
#  {'budget': 28.0,
#   'domgross': 71.4,
#   'budget_2013$': 28.0,
#   'domgross_2013$': 71.4},
#  {'budget': 35.0,
#   'domgross': 82.83,
#   'budget_2013$': 35.0,
#   'domgross_2013$': 82.83},
#  {'budget': 30.0,
#   'domgross': 32.17,
#   'budget_2013$': 30.0,
#   'domgross_2013$': 32.17},
#  {'budget': 190.0,
#   'domgross': 228.78,
#   'budget_2013$': 190.0,
#   'domgross_2013$': 228.78},
#  {'budget': 20.0,
#   'domgross': 34.34,
#   'budget_2013$': 20.0,
#   'domgross_2013$': 34.34},
#  {'budget': 32.5,
#   'domgross': 21.82,
#   'budget_2013$': 32.5,
#   'domgross_2013$': 21.82},
#  {'budget': 19.0,
#   'domgross': 21.35,
#   'budget_2013$': 19.0,
#   'domgross_2013$': 21.35},
#  {'budget': 13.0,
#   'domgross': 51.87,
#   'budget_2013$': 13.0,
#   'domgross_2013$': 51.87},
#  {'budget': 20.0,
#   'domgross': 137.4,
#   'budget_2013$': 20.0,
#   'domgross_2013$': 137.4},
#  {'budget': 25.0,
#   'domgross': 16.97,
#   'budget_2013$': 25.0,
#   'domgross_2013$': 16.97},
#  {'budget': 135.0,
#   'domgross': 187.17,
#   'budget_2013$': 135.0,
#   'domgross_2013$': 187.17},
#  {'budget': 30.0,
#   'domgross': 36.92,
#   'budget_2013$': 30.0,
#   'domgross_2013$': 36.92},
#  {'budget': 26.0,
#   'domgross': 3.25,
#   'budget_2013$': 26.0,
#   'domgross_2013$': 3.25},
#  {'budget': 19.2,
#   'domgross': nan,
#   'budget_2013$': 19.2,
#   'domgross_2013$': nan},
#  {'budget': 190.0,
#   'domgross': 144.84,
#   'budget_2013$': 190.0,
#   'domgross_2013$': 144.84},
#  {'budget': 103.0,
#   'domgross': 112.2,
#   'budget_2013$': 103.0,
#   'domgross_2013$': 112.2},
#  {'budget': 43.0,
#   'domgross': 159.58,
#   'budget_2013$': 43.0,
#   'domgross_2013$': 159.58},
#  {'budget': 250.0,
#   'domgross': 257.4,
#   'budget_2013$': 250.0,
#   'domgross_2013$': 257.4},
#  {'budget': 50.0,
#   'domgross': 26.62,
#   'budget_2013$': 50.0,
#   'domgross_2013$': 26.62},
#  {'budget': 130.0,
#   'domgross': 424.09,
#   'budget_2013$': 130.0,
#   'domgross_2013$': 424.09},
#  {'budget': 32.0,
#   'domgross': 22.54,
#   'budget_2013$': 32.0,
#   'domgross_2013$': 22.54},
#  {'budget': 58.0,
#   'domgross': 44.67,
#   'budget_2013$': 58.0,
#   'domgross_2013$': 44.67},
#  {'budget': 4.0,
#   'domgross': 15.18,
#   'budget_2013$': 4.0,
#   'domgross_2013$': 15.18},
#  {'budget': 275.0,
#   'domgross': 89.29,
#   'budget_2013$': 275.0,
#   'domgross_2013$': 89.29},
#  {'budget': 60.0,
#   'domgross': 31.17,
#   'budget_2013$': 60.0,
#   'domgross_2013$': 31.17},
#  {'budget': 3.0,
#   'domgross': 64.47,
#   'budget_2013$': 3.0,
#   'domgross_2013$': 64.47},
#  {'budget': 110.0,
#   'domgross': 71.02,
#   'budget_2013$': 110.0,
#   'domgross_2013$': 71.02},
#  {'budget': 1.5,
#   'domgross': 3.49,
#   'budget_2013$': 1.5,
#   'domgross_2013$': 3.49},
#  {'budget': 5.0,
#   'domgross': 21.5,
#   'budget_2013$': 5.0,
#   'domgross_2013$': 21.5},
#  {'budget': 100.0,
#   'domgross': 115.7,
#   'budget_2013$': 100.0,
#   'domgross_2013$': 115.7},
#  {'budget': 115.0,
#   'domgross': 132.56,
#   'budget_2013$': 115.0,
#   'domgross_2013$': 132.56},
#  {'budget': 20.0,
#   'domgross': 26.0,
#   'budget_2013$': 20.0,
#   'domgross_2013$': 26.0},
#  {'budget': 32.0,
#   'domgross': 101.47,
#   'budget_2013$': 32.0,
#   'domgross_2013$': 101.47},
#  {'budget': 170.0,
#   'domgross': 204.67,
#   'budget_2013$': 170.0,
#   'domgross_2013$': 204.67},
#  {'budget': 16.0,
#   'domgross': 2.32,
#   'budget_2013$': 16.0,
#   'domgross_2013$': 2.32},
#  {'budget': 135.0,
#   'domgross': 83.03,
#   'budget_2013$': 135.0,
#   'domgross_2013$': 83.03},
#  {'budget': 30.0,
#   'domgross': 66.38,
#   'budget_2013$': 30.0,
#   'domgross_2013$': 66.38},
#  {'budget': 37.0,
#   'domgross': 150.39,
#   'budget_2013$': 37.0,
#   'domgross_2013$': 150.39},
#  {'budget': 150.0,
#   'domgross': 73.1,
#   'budget_2013$': 150.0,
#   'domgross_2013$': 73.1},
#  {'budget': 190.0,
#   'domgross': 202.36,
#   'budget_2013$': 190.0,
#   'domgross_2013$': 202.36},
#  {'budget': 67.5,
#   'domgross': 37.52,
#   'budget_2013$': 68.49,
#   'domgross_2013$': 38.07},
#  {'budget': 12.0,
#   'domgross': 70.01,
#   'budget_2013$': 12.18,
#   'domgross_2013$': 71.04},
#  {'budget': 9.7,
#   'domgross': 6.74,
#   'budget_2013$': 9.84,
#   'domgross_2013$': 6.84},
#  {'budget': 49.0,
#   'domgross': 12.82,
#   'budget_2013$': 49.72,
#   'domgross_2013$': 13.0},
#  {'budget': 44.5,
#   'domgross': 136.03,
#   'budget_2013$': 45.15,
#   'domgross_2013$': 138.02},
#  {'budget': 209.0,
#   'domgross': 65.24,
#   'budget_2013$': 212.06,
#   'domgross_2013$': 66.19},
#  {'budget': 1.8,
#   'domgross': 12.8,
#   'budget_2013$': 1.83,
#   'domgross_2013$': 12.98},
#  {'budget': 1.2, 'domgross': 0.6, 'budget_2013$': 1.22, 'domgross_2013$': 0.6},
#  {'budget': 185.0,
#   'domgross': 237.28,
#   'budget_2013$': 187.71,
#   'domgross_2013$': 240.76},
#  {'budget': 55.0,
#   'domgross': 9.49,
#   'budget_2013$': 55.81,
#   'domgross_2013$': 9.63},
#  {'budget': 1.0,
#   'domgross': 18.12,
#   'budget_2013$': 1.01,
#   'domgross_2013$': 18.38},
#  {'budget': 12.0,
#   'domgross': 64.58,
#   'budget_2013$': 12.18,
#   'domgross_2013$': 65.52},
#  {'budget': 102.0,
#   'domgross': 27.11,
#   'budget_2013$': 103.49,
#   'domgross_2013$': 27.51},
#  {'budget': 25.0,
#   'domgross': 66.53,
#   'budget_2013$': 25.37,
#   'domgross_2013$': 67.5},
#  {'budget': 100.0,
#   'domgross': 162.81,
#   'budget_2013$': 101.46,
#   'domgross_2013$': 165.19},
#  {'budget': 31.0,
#   'domgross': 93.77,
#   'budget_2013$': 31.45,
#   'domgross_2013$': 95.15},
#  {'budget': 39.0,
#   'domgross': 35.29,
#   'budget_2013$': 39.57,
#   'domgross_2013$': 35.8},
#  {'budget': 87.0,
#   'domgross': 165.09,
#   'budget_2013$': 88.27,
#   'domgross_2013$': 167.51},
#  {'budget': 85.0,
#   'domgross': 148.31,
#   'budget_2013$': 86.24,
#   'domgross_2013$': 150.48},
#  {'budget': 60.0,
#   'domgross': 80.07,
#   'budget_2013$': 60.88,
#   'domgross_2013$': 81.24},
#  {'budget': 3.45,
#   'domgross': 0.69,
#   'budget_2013$': 3.5,
#   'domgross_2013$': 0.7},
#  {'budget': 275.0,
#   'domgross': 73.06,
#   'budget_2013$': 279.03,
#   'domgross_2013$': 74.13},
#  {'budget': 15.0,
#   'domgross': 14.95,
#   'budget_2013$': 15.22,
#   'domgross_2013$': 15.16},
#  {'budget': 65.0,
#   'domgross': 148.81,
#   'budget_2013$': 65.95,
#   'domgross_2013$': 150.99},
#  {'budget': 120.0,
#   'domgross': 124.99,
#   'budget_2013$': 121.76,
#   'domgross_2013$': 126.82},
#  {'budget': 65.0,
#   'domgross': 182.21,
#   'budget_2013$': 65.95,
#   'domgross_2013$': 184.88},
#  {'budget': 145.0,
#   'domgross': 216.39,
#   'budget_2013$': 147.12,
#   'domgross_2013$': 219.56},
#  {'budget': 215.0,
#   'domgross': 179.02,
#   'budget_2013$': 218.15,
#   'domgross_2013$': 181.64},
#  {'budget': 85.0,
#   'domgross': 64.94,
#   'budget_2013$': 86.24,
#   'domgross_2013$': 65.89},
#  {'budget': 16.0,
#   'domgross': 45.51,
#   'budget_2013$': 16.23,
#   'domgross_2013$': 46.18},
#  {'budget': 8.0,
#   'domgross': 22.55,
#   'budget_2013$': 8.12,
#   'domgross_2013$': 22.88},
#  {'budget': 42.0,
#   'domgross': 26.41,
#   'budget_2013$': 42.61,
#   'domgross_2013$': 26.8},
#  {'budget': 5.0,
#   'domgross': 53.9,
#   'budget_2013$': 5.07,
#   'domgross_2013$': 54.69},
#  {'budget': 60.0,
#   'domgross': 56.0,
#   'budget_2013$': 60.88,
#   'domgross_2013$': 56.82},
#  {'budget': 25.0,
#   'domgross': 77.27,
#   'budget_2013$': 25.37,
#   'domgross_2013$': 78.4},
#  {'budget': 16.0,
#   'domgross': 12.43,
#   'budget_2013$': 16.23,
#   'domgross_2013$': 12.61},
#  {'budget': 17.0,
#   'domgross': 65.0,
#   'budget_2013$': 17.25,
#   'domgross_2013$': 65.95},
#  {'budget': 35.0,
#   'domgross': 20.28,
#   'budget_2013$': 35.51,
#   'domgross_2013$': 20.57},
#  {'budget': 65.0,
#   'domgross': 44.81,
#   'budget_2013$': 65.95,
#   'domgross_2013$': 45.46},
#  {'budget': 58.0,
#   'domgross': 49.88,
#   'budget_2013$': 58.85,
#   'domgross_2013$': 50.61},
#  {'budget': 145.0,
#   'domgross': 103.41,
#   'budget_2013$': 147.12,
#   'domgross_2013$': 104.93},
#  {'budget': 70.0,
#   'domgross': 38.52,
#   'budget_2013$': 71.02,
#   'domgross_2013$': 39.08},
#  {'budget': 33.0,
#   'domgross': 17.14,
#   'budget_2013$': 33.48,
#   'domgross_2013$': 17.39},
#  {'budget': 0.75,
#   'domgross': 4.01,
#   'budget_2013$': 0.76,
#   'domgross_2013$': 4.07},
#  {'budget': 13.5,
#   'domgross': 15.02,
#   'budget_2013$': 13.7,
#   'domgross_2013$': 15.24},
#  {'budget': 20.0,
#   'domgross': 17.53,
#   'budget_2013$': 20.29,
#   'domgross_2013$': 17.79},
#  {'budget': 21.0,
#   'domgross': 132.09,
#   'budget_2013$': 21.31,
#   'domgross_2013$': 134.03},
#  {'budget': 3.0,
#   'domgross': 48.09,
#   'budget_2013$': 3.04,
#   'domgross_2013$': 48.79},
#  {'budget': 200.0,
#   'domgross': 304.36,
#   'budget_2013$': 202.93,
#   'domgross_2013$': 308.82},
#  {'budget': 170.0,
#   'domgross': 155.14,
#   'budget_2013$': 172.49,
#   'domgross_2013$': 157.41},
#  {'budget': 10.0,
#   'domgross': 24.4,
#   'budget_2013$': 10.15,
#   'domgross_2013$': 24.75},
#  {'budget': 5.0,
#   'domgross': 14.12,
#   'budget_2013$': 5.07,
#   'domgross_2013$': 14.33},
#  {'budget': 33.0,
#   'domgross': 35.07,
#   'budget_2013$': 33.48,
#   'domgross_2013$': 35.59},
#  {'budget': 0.06,
#   'domgross': 0.0,
#   'budget_2013$': 0.06,
#   'domgross_2013$': 0.0},
#  {'budget': 50.0,
#   'domgross': 218.67,
#   'budget_2013$': 50.73,
#   'domgross_2013$': 221.87},
#  {'budget': 67.5,
#   'domgross': 36.93,
#   'budget_2013$': 68.49,
#   'domgross_2013$': 37.47},
#  {'budget': 220.0,
#   'domgross': 262.03,
#   'budget_2013$': 223.22,
#   'domgross_2013$': 265.87},
#  {'budget': 60.0,
#   'domgross': 23.39,
#   'budget_2013$': 60.88,
#   'domgross_2013$': 23.73},
#  {'budget': 275.0,
#   'domgross': 448.14,
#   'budget_2013$': 279.03,
#   'domgross_2013$': 454.7},
#  {'budget': 1.0,
#   'domgross': 53.26,
#   'budget_2013$': 1.01,
#   'domgross_2013$': 54.04},
#  {'budget': 65.0,
#   'domgross': 59.65,
#   'budget_2013$': 65.95,
#   'domgross_2013$': 60.52},
#  {'budget': 100.0,
#   'domgross': 85.03,
#   'budget_2013$': 101.46,
#   'domgross_2013$': 86.27},
#  {'budget': 25.0,
#   'domgross': 51.58,
#   'budget_2013$': 25.37,
#   'domgross_2013$': 52.34},
#  {'budget': 250.0,
#   'domgross': 303.0,
#   'budget_2013$': 253.66,
#   'domgross_2013$': 307.44},
#  {'budget': 80.0,
#   'domgross': 408.01,
#   'budget_2013$': 81.17,
#   'domgross_2013$': 413.98},
#  {'budget': 40.0,
#   'domgross': 19.02,
#   'budget_2013$': 40.59,
#   'domgross_2013$': 19.3},
#  {'budget': 15.0,
#   'domgross': 15.63,
#   'budget_2013$': 15.22,
#   'domgross_2013$': 15.86},
#  {'budget': 37.5,
#   'domgross': 16.25,
#   'budget_2013$': 38.05,
#   'domgross_2013$': 16.48},
#  {'budget': 55.0,
#   'domgross': 31.05,
#   'budget_2013$': 55.81,
#   'domgross_2013$': 31.51},
#  {'budget': 15.0,
#   'domgross': 21.4,
#   'budget_2013$': 15.22,
#   'domgross_2013$': 21.72},
#  {'budget': 136.2,
#   'domgross': 292.32,
#   'budget_2013$': 138.19,
#   'domgross_2013$': 296.6},
#  {'budget': 8.74,
#   'domgross': 125.01,
#   'budget_2013$': 8.87,
#   'domgross_2013$': 126.84},
#  {'budget': 55.0,
#   'domgross': 34.35,
#   'budget_2013$': 55.81,
#   'domgross_2013$': 34.86},
#  {'budget': 15.0,
#   'domgross': 54.33,
#   'budget_2013$': 15.22,
#   'domgross_2013$': 55.13},
#  {'budget': 6.0,
#   'domgross': 11.49,
#   'budget_2013$': 6.09,
#   'domgross_2013$': 11.66},
#  {'budget': 12.0,
#   'domgross': 91.55,
#   'budget_2013$': 12.18,
#   'domgross_2013$': 92.89},
#  {'budget': 21.5,
#   'domgross': 16.68,
#   'budget_2013$': 21.81,
#   'domgross_2013$': 16.93},
#  {'budget': 125.0,
#   'domgross': 58.88,
#   'budget_2013$': 126.83,
#   'domgross_2013$': 59.74},
#  {'budget': 70.0,
#   'domgross': 62.32,
#   'budget_2013$': 71.02,
#   'domgross_2013$': 63.23},
#  {'budget': 32.5,
#   'domgross': 17.29,
#   'budget_2013$': 32.98,
#   'domgross_2013$': 17.54},
#  {'budget': 37.5,
#   'domgross': 41.15,
#   'budget_2013$': 38.05,
#   'domgross_2013$': 41.75},
#  {'budget': 19.0,
#   'domgross': 5.31,
#   'budget_2013$': 19.28,
#   'domgross_2013$': 5.39},
#  {'budget': 150.0,
#   'domgross': 83.67,
#   'budget_2013$': 152.2,
#   'domgross_2013$': 84.89},
#  {'budget': 165.0,
#   'domgross': 189.41,
#   'budget_2013$': 167.42,
#   'domgross_2013$': 192.19},
#  {'budget': 52.5,
#   'domgross': 95.72,
#   'budget_2013$': 53.27,
#   'domgross_2013$': 97.12},
#  {'budget': 28.0,
#   'domgross': 37.05,
#   'budget_2013$': 29.0,
#   'domgross_2013$': 38.38},
#  {'budget': 8.0,
#   'domgross': 35.02,
#   'budget_2013$': 8.29,
#   'domgross_2013$': 36.27},
#  {'budget': 20.0,
#   'domgross': 5.7,
#   'budget_2013$': 20.71,
#   'domgross_2013$': 5.91},
#  {'budget': 4.0, 'domgross': nan, 'budget_2013$': 4.14, 'domgross_2013$': nan},
#  {'budget': 20.0,
#   'domgross': 35.06,
#   'budget_2013$': 20.71,
#   'domgross_2013$': 36.31},
#  {'budget': 0.17,
#   'domgross': 1.32,
#   'budget_2013$': 0.18,
#   'domgross_2013$': 1.37},
#  {'budget': 5.0,
#   'domgross': 17.69,
#   'budget_2013$': 5.18,
#   'domgross_2013$': 18.32},
#  {'budget': 85.0,
#   'domgross': 46.46,
#   'budget_2013$': 88.03,
#   'domgross_2013$': 48.12},
#  {'budget': 13.0,
#   'domgross': 1.02,
#   'budget_2013$': 13.46,
#   'domgross_2013$': 1.06},
#  {'budget': 19.0,
#   'domgross': 100.29,
#   'budget_2013$': 19.68,
#   'domgross_2013$': 103.87},
#  {'budget': 70.0,
#   'domgross': 83.55,
#   'budget_2013$': 72.5,
#   'domgross_2013$': 86.53},
#  {'budget': 17.0,
#   'domgross': 27.87,
#   'budget_2013$': 17.61,
#   'domgross_2013$': 28.86},
#  {'budget': 4.5,
#   'domgross': 0.2,
#   'budget_2013$': 4.66,
#   'domgross_2013$': 0.21},
#  {'budget': 32.5,
#   'domgross': 169.11,
#   'budget_2013$': 33.66,
#   'domgross_2013$': 175.14},
#  {'budget': 140.0,
#   'domgross': 176.65,
#   'budget_2013$': 145.0,
#   'domgross_2013$': 182.96},
#  {'budget': 200.0,
#   'domgross': 191.45,
#   'budget_2013$': 207.14,
#   'domgross_2013$': 198.28},
#  {'budget': 0.9,
#   'domgross': 0.45,
#   'budget_2013$': 0.93,
#   'domgross_2013$': 0.47},
#  {'budget': 40.0,
#   'domgross': 36.67,
#   'budget_2013$': 41.43,
#   'domgross_2013$': 37.97},
#  {'budget': 20.0,
#   'domgross': 38.26,
#   'budget_2013$': 20.71,
#   'domgross_2013$': 39.63},
#  {'budget': 60.0,
#   'domgross': 75.66,
#   'budget_2013$': 62.14,
#   'domgross_2013$': 78.36},
#  {'budget': 10.0,
#   'domgross': 0.75,
#   'budget_2013$': 10.36,
#   'domgross_2013$': 0.78},
#  {'budget': 163.0,
#   'domgross': 100.24,
#   'budget_2013$': 168.82,
#   'domgross_2013$': 103.82},
#  {'budget': 10.0,
#   'domgross': nan,
#   'budget_2013$': 10.36,
#   'domgross_2013$': nan},
#  {'budget': 18.0,
#   'domgross': 52.7,
#   'budget_2013$': 18.64,
#   'domgross_2013$': 54.58},
#  {'budget': 37.0,
#   'domgross': 72.29,
#   'budget_2013$': 38.32,
#   'domgross_2013$': 74.87},
#  {'budget': 50.0,
#   'domgross': 21.3,
#   'budget_2013$': 51.78,
#   'domgross_2013$': 22.06},
#  {'budget': 15.0,
#   'domgross': 35.06,
#   'budget_2013$': 15.54,
#   'domgross_2013$': 36.31},
#  {'budget': 125.0,
#   'domgross': 209.84,
#   'budget_2013$': 129.46,
#   'domgross_2013$': 217.33},
#  {'budget': 40.0,
#   'domgross': 42.59,
#   'budget_2013$': 41.43,
#   'domgross_2013$': 44.11},
#  {'budget': 24.0,
#   'domgross': 51.8,
#   'budget_2013$': 24.86,
#   'domgross_2013$': 53.65},
#  {'budget': 30.0,
#   'domgross': 18.3,
#   'budget_2013$': 31.07,
#   'domgross_2013$': 18.95},
#  {'budget': 200.0,
#   'domgross': 116.6,
#   'budget_2013$': 207.14,
#   'domgross_2013$': 120.76},
#  {'budget': 36.0,
#   'domgross': 45.06,
#   'budget_2013$': 37.28,
#   'domgross_2013$': 46.67},
#  {'budget': 30.0,
#   'domgross': 40.26,
#   'budget_2013$': 31.07,
#   'domgross_2013$': 41.7},
#  {'budget': 125.0,
#   'domgross': 381.01,
#   'budget_2013$': 129.46,
#   'domgross_2013$': 394.61},
#  {'budget': 23.0,
#   'domgross': 18.94,
#   'budget_2013$': 23.82,
#   'domgross_2013$': 19.62},
#  {'budget': 7.0,
#   'domgross': 0.38,
#   'budget_2013$': 7.25,
#   'domgross_2013$': 0.4},
#  {'budget': 1.8,
#   'domgross': 0.84,
#   'budget_2013$': 1.86,
#   'domgross_2013$': 0.87},
#  {'budget': 3.0,
#   'domgross': 0.7,
#   'budget_2013$': 3.11,
#   'domgross_2013$': 0.73},
#  {'budget': 63.0,
#   'domgross': 108.09,
#   'budget_2013$': 65.25,
#   'domgross_2013$': 111.94},
#  {'budget': 35.0,
#   'domgross': 117.54,
#   'budget_2013$': 36.25,
#   'domgross_2013$': 121.73},
#  {'budget': 180.0,
#   'domgross': 73.86,
#   'budget_2013$': 186.42,
#   'domgross_2013$': 76.5},
#  {'budget': 50.0,
#   'domgross': 55.1,
#   'budget_2013$': 51.78,
#   'domgross_2013$': 57.07},
#  {'budget': 75.0,
#   'domgross': 83.5,
#   'budget_2013$': 77.68,
#   'domgross_2013$': 86.48},
#  {'budget': 35.0,
#   'domgross': 37.55,
#   'budget_2013$': 36.25,
#   'domgross_2013$': 38.89},
#  {'budget': 5.5,
#   'domgross': 5.58,
#   'budget_2013$': 5.7,
#   'domgross_2013$': 5.78},
#  {'budget': 100.0,
#   'domgross': 0.31,
#   'budget_2013$': 103.57,
#   'domgross_2013$': 0.32},
#  {'budget': 45.0,
#   'domgross': 8.31,
#   'budget_2013$': 46.61,
#   'domgross_2013$': 8.6},
#  {'budget': 7.0,
#   'domgross': 37.3,
#   'budget_2013$': 7.25,
#   'domgross_2013$': 38.63},
#  {'budget': 80.0,
#   'domgross': 103.03,
#   'budget_2013$': 82.86,
#   'domgross_2013$': 106.71},
#  {'budget': 0.8,
#   'domgross': 0.03,
#   'budget_2013$': 0.83,
#   'domgross_2013$': 0.03},
#  {'budget': 70.0,
#   'domgross': 25.12,
#   'budget_2013$': 72.5,
#   'domgross_2013$': 26.02},
#  {'budget': 150.0,
#   'domgross': 165.25,
#   'budget_2013$': 155.35,
#   'domgross_2013$': 171.15},
#  {'budget': 5.5,
#   'domgross': 0.61,
#   'budget_2013$': 5.7,
#   'domgross_2013$': 0.63},
#  {'budget': 0.25,
#   'domgross': 3.4,
#   'budget_2013$': 0.26,
#   'domgross_2013$': 3.52},
#  {'budget': 27.0,
#   'domgross': 79.25,
#   'budget_2013$': 27.96,
#   'domgross_2013$': 82.08},
#  {'budget': 14.0,
#   'domgross': 0.05,
#   'budget_2013$': 14.5,
#   'domgross_2013$': 0.05},
#  {'budget': 3.4,
#   'domgross': 5.35,
#   'budget_2013$': 3.52,
#   'domgross_2013$': 5.54},
#  {'budget': 150.0,
#   'domgross': 21.39,
#   'budget_2013$': 155.35,
#   'domgross_2013$': 22.16},
#  {'budget': 1.0,
#   'domgross': 2.98,
#   'budget_2013$': 1.04,
#   'domgross_2013$': 3.09},
#  {'budget': 9.4,
#   'domgross': 3.03,
#   'budget_2013$': 9.74,
#   'domgross_2013$': 3.14},
#  {'budget': 30.0,
#   'domgross': 56.82,
#   'budget_2013$': 31.07,
#   'domgross_2013$': 58.84},
#  {'budget': 145.0,
#   'domgross': 209.4,
#   'budget_2013$': 150.18,
#   'domgross_2013$': 216.87},
#  {'budget': 50.0,
#   'domgross': 75.61,
#   'budget_2013$': 51.78,
#   'domgross_2013$': 78.3},
#  {'budget': 55.0,
#   'domgross': 68.22,
#   'budget_2013$': 56.96,
#   'domgross_2013$': 70.66},
#  {'budget': 26.0,
#   'domgross': 54.54,
#   'budget_2013$': 26.93,
#   'domgross_2013$': 56.49},
#  {'budget': 25.0,
#   'domgross': 70.66,
#   'budget_2013$': 25.89,
#   'domgross_2013$': 73.18},
#  {'budget': 1.0,
#   'domgross': 5.36,
#   'budget_2013$': 1.04,
#   'domgross_2013$': 5.55},
#  {'budget': 5.0,
#   'domgross': 24.81,
#   'budget_2013$': 5.18,
#   'domgross_2013$': 25.7},
#  {'budget': 5.0,
#   'domgross': 104.03,
#   'budget_2013$': 5.18,
#   'domgross_2013$': 107.74},
#  {'budget': 40.0,
#   'domgross': 37.41,
#   'budget_2013$': 41.43,
#   'domgross_2013$': 38.75},
#  {'budget': 250.0,
#   'domgross': 241.06,
#   'budget_2013$': 258.92,
#   'domgross_2013$': 249.67},
#  {'budget': 60.0,
#   'domgross': 29.14,
#   'budget_2013$': 62.14,
#   'domgross_2013$': 30.18},
#  {'budget': 130.0,
#   'domgross': 149.26,
#   'budget_2013$': 134.64,
#   'domgross_2013$': 154.59},
#  {'budget': 135.0,
#   'domgross': 123.26,
#   'budget_2013$': 139.82,
#   'domgross_2013$': 127.66},
#  {'budget': 110.0,
#   'domgross': 85.46,
#   'budget_2013$': 113.93,
#   'domgross_2013$': 88.51},
#  {'budget': 42.0,
#   'domgross': 37.66,
#   'budget_2013$': 43.5,
#   'domgross_2013$': 39.01},
#  {'budget': 4.0,
#   'domgross': 1.07,
#   'budget_2013$': 4.14,
#   'domgross_2013$': 1.1},
#  {'budget': 8.0,
#   'domgross': 0.16,
#   'budget_2013$': 8.29,
#   'domgross_2013$': 0.17},
#  {'budget': 90.0,
#   'domgross': 143.62,
#   'budget_2013$': 93.21,
#   'domgross_2013$': 148.75},
#  {'budget': 93.0,
#   'domgross': 176.76,
#   'budget_2013$': 96.32,
#   'domgross_2013$': 183.07},
#  {'budget': 6.5,
#   'domgross': 4.0,
#   'budget_2013$': 6.73,
#   'domgross_2013$': 4.15},
#  {'budget': 6.0,
#   'domgross': 1.35,
#   'budget_2013$': 6.21,
#   'domgross_2013$': 1.4},
#  {'budget': 18.0,
#   'domgross': 43.85,
#   'budget_2013$': 18.64,
#   'domgross_2013$': 45.42},
#  {'budget': 32.0,
#   'domgross': 54.71,
#   'budget_2013$': 33.14,
#   'domgross_2013$': 56.66},
#  {'budget': 25.0,
#   'domgross': 10.32,
#   'budget_2013$': 25.89,
#   'domgross_2013$': 10.69},
#  {'budget': 75.0,
#   'domgross': 36.39,
#   'budget_2013$': 77.68,
#   'domgross_2013$': 37.69},
#  {'budget': 50.0,
#   'domgross': 127.0,
#   'budget_2013$': 51.78,
#   'domgross_2013$': 131.54},
#  {'budget': 4.75,
#   'domgross': 1.73,
#   'budget_2013$': 4.92,
#   'domgross_2013$': 1.79},
#  {'budget': 50.2,
#   'domgross': 62.5,
#   'budget_2013$': 51.99,
#   'domgross_2013$': 64.73},
#  {'budget': 130.0,
#   'domgross': 77.59,
#   'budget_2013$': 134.64,
#   'domgross_2013$': 80.36},
#  {'budget': 16.0,
#   'domgross': 44.67,
#   'budget_2013$': 16.57,
#   'domgross_2013$': 46.26},
#  {'budget': 10.0,
#   'domgross': 46.38,
#   'budget_2013$': 10.36,
#   'domgross_2013$': 48.04},
#  {'budget': 30.0,
#   'domgross': 42.07,
#   'budget_2013$': 31.07,
#   'domgross_2013$': 43.57},
#  {'budget': 34.8,
#   'domgross': 21.44,
#   'budget_2013$': 36.04,
#   'domgross_2013$': 22.21},
#  {'budget': 3.0,
#   'domgross': 0.02,
#   'budget_2013$': 3.11,
#   'domgross_2013$': 0.02},
#  {'budget': 1.0,
#   'domgross': 0.57,
#   'budget_2013$': 1.04,
#   'domgross_2013$': 0.59},
#  {'budget': 90.0,
#   'domgross': 102.52,
#   'budget_2013$': 93.21,
#   'domgross_2013$': 106.17},
#  {'budget': 110.0,
#   'domgross': 98.78,
#   'budget_2013$': 113.93,
#   'domgross_2013$': 102.31},
#  {'budget': 6.0,
#   'domgross': 5.36,
#   'budget_2013$': 6.21,
#   'domgross_2013$': 5.55},
#  {'budget': 25.0,
#   'domgross': 169.71,
#   'budget_2013$': 25.89,
#   'domgross_2013$': 175.76},
#  {'budget': 14.0,
#   'domgross': 29.96,
#   'budget_2013$': 14.5,
#   'domgross_2013$': 31.03},
#  {'budget': 40.0,
#   'domgross': 58.01,
#   'budget_2013$': 41.43,
#   'domgross_2013$': 60.08},
#  {'budget': 42.5,
#   'domgross': 29.12,
#   'budget_2013$': 44.02,
#   'domgross_2013$': 30.16},
#  {'budget': 45.0,
#   'domgross': 88.63,
#   'budget_2013$': 46.61,
#   'domgross_2013$': 91.79},
#  {'budget': 37.0,
#   'domgross': 33.05,
#   'budget_2013$': 38.32,
#   'domgross_2013$': 34.23},
#  {'budget': 16.0,
#   'domgross': 37.3,
#   'budget_2013$': 16.57,
#   'domgross_2013$': 38.63},
#  {'budget': 110.0,
#   'domgross': 142.61,
#   'budget_2013$': 113.93,
#   'domgross_2013$': 147.7},
#  {'budget': 90.0,
#   'domgross': 20.38,
#   'budget_2013$': 93.21,
#   'domgross_2013$': 21.11},
#  {'budget': 35.0,
#   'domgross': 13.31,
#   'budget_2013$': 36.25,
#   'domgross_2013$': 13.78},
#  {'budget': 127.5,
#   'domgross': 281.29,
#   'budget_2013$': 132.05,
#   'domgross_2013$': 291.33},
#  {'budget': 150.0,
#   'domgross': 181.03,
#   'budget_2013$': 155.35,
#   'domgross_2013$': 187.49},
#  {'budget': 21.0,
#   'domgross': 24.15,
#   'budget_2013$': 21.75,
#   'domgross_2013$': 25.01},
#  {'budget': 85.0,
#   'domgross': 78.05,
#   'budget_2013$': 88.03,
#   'domgross_2013$': 80.83},
#  {'budget': 195.0,
#   'domgross': 352.39,
#   'budget_2013$': 201.96,
#   'domgross_2013$': 364.97},
#  {'budget': 70.0,
#   'domgross': 79.88,
#   'budget_2013$': 72.5,
#   'domgross_2013$': 82.73},
#  {'budget': 25.0,
#   'domgross': 13.66,
#   'budget_2013$': 25.89,
#   'domgross_2013$': 14.14},
#  {'budget': 50.0,
#   'domgross': 75.62,
#   'budget_2013$': 51.78,
#   'domgross_2013$': 78.32},
#  {'budget': 0.19,
#   'domgross': 0.48,
#   'budget_2013$': 0.2,
#   'domgross_2013$': 0.5},
#  {'budget': 20.0,
#   'domgross': 14.01,
#   'budget_2013$': 20.71,
#   'domgross_2013$': 14.51},
#  {'budget': 30.0,
#   'domgross': 26.69,
#   'budget_2013$': 31.07,
#   'domgross_2013$': 27.65},
#  {'budget': 160.0,
#   'domgross': 146.41,
#   'budget_2013$': 165.71,
#   'domgross_2013$': 151.63},
#  {'budget': 12.0,
#   'domgross': 16.31,
#   'budget_2013$': 12.43,
#   'domgross_2013$': 16.89},
#  {'budget': 0.12,
#   'domgross': 1.6,
#   'budget_2013$': 0.12,
#   'domgross_2013$': 1.65},
#  {'budget': 18.0,
#   'domgross': 18.34,
#   'budget_2013$': 19.23,
#   'domgross_2013$': 19.59},
#  {'budget': 200.0,
#   'domgross': 334.19,
#   'budget_2013$': 213.65,
#   'domgross_2013$': 356.99},
#  {'budget': 4.2,
#   'domgross': 1.04,
#   'budget_2013$': 4.49,
#   'domgross_2013$': 1.12},
#  {'budget': 8.0,
#   'domgross': 3.21,
#   'budget_2013$': 8.55,
#   'domgross_2013$': 3.42},
#  {'budget': 30.0,
#   'domgross': 7.5,
#   'budget_2013$': 32.05,
#   'domgross_2013$': 8.01},
#  {'budget': 3.2,
#   'domgross': 5.79,
#   'budget_2013$': 3.42,
#   'domgross_2013$': 6.19},
#  {'budget': 35.0,
#   'domgross': 5.1,
#   'budget_2013$': 37.39,
#   'domgross_2013$': 5.45},
#  {'budget': 13.0,
#   'domgross': 106.95,
#   'budget_2013$': 13.89,
#   'domgross_2013$': 114.25},
#  {'budget': 1.0,
#   'domgross': 9.74,
#   'budget_2013$': 1.07,
#   'domgross_2013$': 10.4},
#  {'budget': 55.0,
#   'domgross': 39.44,
#   'budget_2013$': 58.75,
#   'domgross_2013$': 42.13},
#  {'budget': 12.5,
#   'domgross': 2.04,
#   'budget_2013$': 13.35,
#   'domgross_2013$': 2.18},
#  {'budget': 15.0,
#   'domgross': 0.12,
#   'budget_2013$': 16.02,
#   'domgross_2013$': 0.13},
#  {'budget': 44.0,
#   'domgross': 31.21,
#   'budget_2013$': 47.0,
#   'domgross_2013$': 33.34},
#  {'budget': 125.0,
#   'domgross': 163.21,
#   'budget_2013$': 133.53,
#   'domgross_2013$': 174.35},
#  {'budget': 12.5,
#   'domgross': 6.8,
#   'budget_2013$': 13.35,
#   'domgross_2013$': 7.26},
#  {'budget': 37.0,
#   'domgross': 44.88,
#   'budget_2013$': 39.52,
#   'domgross_2013$': 47.94},
#  {'budget': 15.0,
#   'domgross': 20.22,
#   'budget_2013$': 16.02,
#   'domgross_2013$': 21.6},
#  {'budget': 7.0,
#   'domgross': 7.47,
#   'budget_2013$': 7.48,
#   'domgross_2013$': 7.98},
#  {'budget': 55.0,
#   'domgross': 98.71,
#   'budget_2013$': 58.75,
#   'domgross_2013$': 105.45},
#  {'budget': 25.0,
#   'domgross': 80.01,
#   'budget_2013$': 26.71,
#   'domgross_2013$': 85.47},
#  {'budget': 69.0,
#   'domgross': 251.51,
#   'budget_2013$': 73.71,
#   'domgross_2013$': 268.68},
#  {'budget': 10.0,
#   'domgross': 33.68,
#   'budget_2013$': 10.68,
#   'domgross_2013$': 35.98},
#  {'budget': 15.0,
#   'domgross': 64.0,
#   'budget_2013$': 16.02,
#   'domgross_2013$': 68.37},
#  {'budget': 69.0,
#   'domgross': 73.03,
#   'budget_2013$': 73.71,
#   'domgross_2013$': 78.01},
#  {'budget': 25.0,
#   'domgross': 24.05,
#   'budget_2013$': 26.71,
#   'domgross_2013$': 25.69},
#  {'budget': 65.0,
#   'domgross': 100.54,
#   'budget_2013$': 69.44,
#   'domgross_2013$': 107.4},
#  {'budget': 20.0,
#   'domgross': 1.19,
#   'budget_2013$': 21.36,
#   'domgross_2013$': 1.27},
#  {'budget': 8.0,
#   'domgross': 58.4,
#   'budget_2013$': 8.55,
#   'domgross_2013$': 62.39},
#  {'budget': 60.0,
#   'domgross': 80.57,
#   'budget_2013$': 64.09,
#   'domgross_2013$': 86.07},
#  {'budget': 60.0,
#   'domgross': 43.31,
#   'budget_2013$': 64.09,
#   'domgross_2013$': 46.27},
#  {'budget': 5.0,
#   'domgross': 2.71,
#   'budget_2013$': 5.34,
#   'domgross_2013$': 2.9},
#  {'budget': 50.0,
#   'domgross': 11.5,
#   'budget_2013$': 53.41,
#   'domgross_2013$': 12.28},
#  {'budget': 12.0,
#   'domgross': 23.24,
#   'budget_2013$': 12.82,
#   'domgross_2013$': 24.83},
#  {'budget': 21.0,
#   'domgross': 37.73,
#   'budget_2013$': 22.43,
#   'domgross_2013$': 40.3},
#  {'budget': 150.0,
#   'domgross': 393.05,
#   'budget_2013$': 160.23,
#   'domgross_2013$': 419.87},
#  {'budget': 40.0,
#   'domgross': 61.15,
#   'budget_2013$': 42.73,
#   'domgross_2013$': 65.33},
#  {'budget': 32.0,
#   'domgross': 17.8,
#   'budget_2013$': 34.18,
#   'domgross_2013$': 19.02},
#  {'budget': 100.0,
#   'domgross': 35.5,
#   'budget_2013$': 106.82,
#   'domgross_2013$': 37.92},
#  {'budget': 75.0,
#   'domgross': 162.0,
#   'budget_2013$': 80.12,
#   'domgross_2013$': 173.05},
#  {'budget': 9.9,
#   'domgross': 0.46,
#   'budget_2013$': 10.58,
#   'domgross_2013$': 0.49},
#  {'budget': 125.0,
#   'domgross': 295.98,
#   'budget_2013$': 133.53,
#   'domgross_2013$': 316.18},
#  {'budget': 36.0,
#   'domgross': 50.27,
#   'budget_2013$': 38.46,
#   'domgross_2013$': 53.7},
#  {'budget': 165.0,
#   'domgross': 217.58,
#   'budget_2013$': 176.26,
#   'domgross_2013$': 232.43},
#  {'budget': 10.0,
#   'domgross': 5.01,
#   'budget_2013$': 10.68,
#   'domgross_2013$': 5.35},
#  {'budget': 160.0,
#   'domgross': 292.58,
#   'budget_2013$': 170.92,
#   'domgross_2013$': 312.54},
#  {'budget': 1.5,
#   'domgross': 54.01,
#   'budget_2013$': 1.6,
#   'domgross_2013$': 57.69},
#  {'budget': 170.0,
#   'domgross': 312.43,
#   'budget_2013$': 181.6,
#   'domgross_2013$': 333.75},
#  {'budget': 8.0,
#   'domgross': 6.36,
#   'budget_2013$': 8.55,
#   'domgross_2013$': 6.8},
#  {'budget': 28.0,
#   'domgross': 48.07,
#   'budget_2013$': 29.91,
#   'domgross_2013$': 51.35},
#  {'budget': 117.0,
#   'domgross': 76.42,
#   'budget_2013$': 124.98,
#   'domgross_2013$': 81.64},
#  {'budget': 26.0,
#   'domgross': 40.17,
#   'budget_2013$': 27.77,
#   'domgross_2013$': 42.91},
#  {'budget': 20.0,
#   'domgross': 12.13,
#   'budget_2013$': 21.36,
#   'domgross_2013$': 12.96},
#  {'budget': 30.0,
#   'domgross': 53.03,
#   'budget_2013$': 32.05,
#   'domgross_2013$': 56.65},
#  {'budget': 30.0,
#   'domgross': 32.37,
#   'budget_2013$': 32.05,
#   'domgross_2013$': 34.58},
#  {'budget': 12.5,
#   'domgross': 26.59,
#   'budget_2013$': 13.35,
#   'domgross_2013$': 28.41},
#  {'budget': 8.0,
#   'domgross': 1.1,
#   'budget_2013$': 8.55,
#   'domgross_2013$': 1.17},
#  {'budget': 2.0,
#   'domgross': 0.98,
#   'budget_2013$': 2.14,
#   'domgross_2013$': 1.04},
#  {'budget': 130.0,
#   'domgross': 148.42,
#   'budget_2013$': 138.87,
#   'domgross_2013$': 158.54},
#  {'budget': 0.5,
#   'domgross': 0.24,
#   'budget_2013$': 0.53,
#   'domgross_2013$': 0.25},
#  {'budget': 40.0,
#   'domgross': 31.01,
#   'budget_2013$': 42.73,
#   'domgross_2013$': 33.13},
#  {'budget': 35.0,
#   'domgross': 29.2,
#   'budget_2013$': 37.39,
#   'domgross_2013$': 31.19},
#  {'budget': 15.0,
#   'domgross': 2.43,
#   'budget_2013$': 16.02,
#   'domgross_2013$': 2.6},
#  {'budget': 3.0,
#   'domgross': 84.75,
#   'budget_2013$': 3.2,
#   'domgross_2013$': 90.54},
#  {'budget': 95.0,
#   'domgross': 88.77,
#   'budget_2013$': 101.48,
#   'domgross_2013$': 94.83},
#  {'budget': 3.0,
#   'domgross': 4.03,
#   'budget_2013$': 3.2,
#   'domgross_2013$': 4.31},
#  {'budget': 40.0,
#   'domgross': 52.0,
#   'budget_2013$': 42.73,
#   'domgross_2013$': 55.55},
#  {'budget': 200.0,
#   'domgross': 90.76,
#   'budget_2013$': 213.65,
#   'domgross_2013$': 96.95},
#  {'budget': 5.0,
#   'domgross': 2.23,
#   'budget_2013$': 5.34,
#   'domgross_2013$': 2.38},
#  {'budget': 15.0,
#   'domgross': 26.17,
#   'budget_2013$': 16.02,
#   'domgross_2013$': 27.95},
#  {'budget': 60.0,
#   'domgross': 90.38,
#   'budget_2013$': 64.09,
#   'domgross_2013$': 96.55},
#  {'budget': 16.0,
#   'domgross': 19.07,
#   'budget_2013$': 17.09,
#   'domgross_2013$': 20.37},
#  {'budget': 32.0,
#   'domgross': 13.94,
#   'budget_2013$': 34.18,
#   'domgross_2013$': 14.89},
#  {'budget': 210.0,
#   'domgross': 105.49,
#   'budget_2013$': 224.33,
#   'domgross_2013$': 112.68},
#  {'budget': 130.0,
#   'domgross': 118.31,
#   'budget_2013$': 138.87,
#   'domgross_2013$': 126.38},
#  {'budget': 85.0,
#   'domgross': 31.61,
#   'budget_2013$': 90.8,
#   'domgross_2013$': 33.77},
#  {'budget': 35.0,
#   'domgross': 59.7,
#   'budget_2013$': 37.39,
#   'domgross_2013$': 63.77},
#  {'budget': 95.0,
#   'domgross': 95.35,
#   'budget_2013$': 101.48,
#   'domgross_2013$': 101.85},
#  {'budget': 165.0,
#   'domgross': 238.74,
#   'budget_2013$': 176.26,
#   'domgross_2013$': 255.03},
#  {'budget': 80.0,
#   'domgross': 128.01,
#   'budget_2013$': 85.46,
#   'domgross_2013$': 136.75},
#  {'budget': 10.0,
#   'domgross': 21.42,
#   'budget_2013$': 10.68,
#   'domgross_2013$': 22.88},
#  {'budget': 7.0,
#   'domgross': 1.79,
#   'budget_2013$': 7.48,
#   'domgross_2013$': 1.91},
#  {'budget': 1.9,
#   'domgross': 0.47,
#   'budget_2013$': 2.03,
#   'domgross_2013$': 0.5},
#  {'budget': 2.5,
#   'domgross': 0.33,
#   'budget_2013$': 2.67,
#   'domgross_2013$': 0.35},
#  {'budget': 32.0,
#   'domgross': 57.74,
#   'budget_2013$': 34.18,
#   'domgross_2013$': 61.68},
#  {'budget': 260.0,
#   'domgross': 200.82,
#   'budget_2013$': 277.74,
#   'domgross_2013$': 214.52},
#  {'budget': 110.0,
#   'domgross': 77.22,
#   'budget_2013$': 117.51,
#   'domgross_2013$': 82.49},
#  {'budget': 35.0,
#   'domgross': 37.49,
#   'budget_2013$': 37.39,
#   'domgross_2013$': 40.05},
#  {'budget': 155.0,
#   'domgross': 104.39,
#   'budget_2013$': 165.58,
#   'domgross_2013$': 111.51},
#  {'budget': 25.0,
#   'domgross': 11.54,
#   'budget_2013$': 26.71,
#   'domgross_2013$': 12.33},
#  {'budget': 19.0,
#   'domgross': 39.12,
#   'budget_2013$': 20.3,
#   'domgross_2013$': 41.79},
#  {'budget': 20.0,
#   'domgross': 31.18,
#   'budget_2013$': 21.36,
#   'domgross_2013$': 33.3},
#  {'budget': 82.0,
#   'domgross': 103.07,
#   'budget_2013$': 87.6,
#   'domgross_2013$': 110.1},
#  {'budget': 11.0,
#   'domgross': 93.62,
#   'budget_2013$': 11.75,
#   'domgross_2013$': 100.0},
#  {'budget': 45.0,
#   'domgross': 15.54,
#   'budget_2013$': 48.07,
#   'domgross_2013$': 16.6},
#  {'budget': 16.5,
#   'domgross': 39.87,
#   'budget_2013$': 17.63,
#   'domgross_2013$': 42.59},
#  {'budget': 40.0,
#   'domgross': 176.59,
#   'budget_2013$': 42.73,
#   'domgross_2013$': 188.64},
#  {'budget': 4.0,
#   'domgross': 20.81,
#   'budget_2013$': 4.27,
#   'domgross_2013$': 22.23},
#  {'budget': 13.0,
#   'domgross': 0.22,
#   'budget_2013$': 13.89,
#   'domgross_2013$': 0.23},
#  {'budget': 15.0,
#   'domgross': 138.8,
#   'budget_2013$': 16.02,
#   'domgross_2013$': 148.27},
#  {'budget': 150.0,
#   'domgross': 131.77,
#   'budget_2013$': 160.23,
#   'domgross_2013$': 140.76},
#  {'budget': 1.8,
#   'domgross': 41.03,
#   'budget_2013$': 1.92,
#   'domgross_2013$': 43.83},
#  {'budget': 25.0,
#   'domgross': 23.59,
#   'budget_2013$': 26.71,
#   'domgross_2013$': 25.2},
#  {'budget': 30.0,
#   'domgross': 21.15,
#   'budget_2013$': 32.05,
#   'domgross_2013$': 22.59},
#  {'budget': 100.0,
#   'domgross': 119.22,
#   'budget_2013$': 106.82,
#   'domgross_2013$': 127.35},
#  {'budget': 9.5,
#   'domgross': 3.57,
#   'budget_2013$': 10.15,
#   'domgross_2013$': 3.82},
#  {'budget': 40.0,
#   'domgross': 96.96,
#   'budget_2013$': 42.73,
#   'domgross_2013$': 103.58},
#  {'budget': 160.0,
#   'domgross': 63.15,
#   'budget_2013$': 170.92,
#   'domgross_2013$': 67.46},
#  {'budget': 28.0,
#   'domgross': 24.31,
#   'budget_2013$': 29.91,
#   'domgross_2013$': 25.97},
#  {'budget': 19.0,
#   'domgross': 27.76,
#   'budget_2013$': 20.3,
#   'domgross_2013$': 29.65},
#  {'budget': 20.0,
#   'domgross': 0.28,
#   'budget_2013$': 21.36,
#   'domgross_2013$': 0.3},
#  {'budget': 100.0,
#   'domgross': 67.63,
#   'budget_2013$': 106.82,
#   'domgross_2013$': 72.25},
#  {'budget': 37.0,
#   'domgross': 92.19,
#   'budget_2013$': 39.52,
#   'domgross_2013$': 98.48},
#  {'budget': 68.0,
#   'domgross': 300.53,
#   'budget_2013$': 72.64,
#   'domgross_2013$': 321.04},
#  {'budget': 150.0,
#   'domgross': 62.19,
#   'budget_2013$': 160.23,
#   'domgross_2013$': 66.43},
#  {'budget': 0.05,
#   'domgross': 0.39,
#   'budget_2013$': 0.05,
#   'domgross_2013$': 0.42},
#  {'budget': 200.0,
#   'domgross': 415.0,
#   'budget_2013$': 213.65,
#   'domgross_2013$': 443.32},
#  {'budget': 200.0,
#   'domgross': 172.06,
#   'budget_2013$': 213.65,
#   'domgross_2013$': 183.8},
#  {'budget': 35.0,
#   'domgross': 171.24,
#   'budget_2013$': 37.39,
#   'domgross_2013$': 182.93},
#  {'budget': 5.0,
#   'domgross': 0.22,
#   'budget_2013$': 5.34,
#   'domgross_2013$': 0.24},
#  {'budget': 95.0,
#   'domgross': 81.56,
#   'budget_2013$': 101.48,
#   'domgross_2013$': 87.13},
#  {'budget': 52.0,
#   'domgross': 110.49,
#   'budget_2013$': 55.55,
#   'domgross_2013$': 118.02},
#  {'budget': 70.0,
#   'domgross': 52.47,
#   'budget_2013$': 74.78,
#   'domgross_2013$': 56.06},
#  {'budget': 10.0,
#   'domgross': 0.15,
#   'budget_2013$': 10.68,
#   'domgross_2013$': 0.16},
#  {'budget': 8.0,
#   'domgross': 0.11,
#   'budget_2013$': 8.55,
#   'domgross_2013$': 0.12},
#  {'budget': 2.0,
#   'domgross': 6.53,
#   'budget_2013$': 2.14,
#   'domgross_2013$': 6.98},
#  {'budget': 13.0,
#   'domgross': nan,
#   'budget_2013$': 13.89,
#   'domgross_2013$': nan},
#  {'budget': 80.0,
#   'domgross': 100.25,
#   'budget_2013$': 85.46,
#   'domgross_2013$': 107.09},
#  {'budget': 20.0,
#   'domgross': 25.7,
#   'budget_2013$': 21.36,
#   'domgross_2013$': 27.46},
#  {'budget': 15.0,
#   'domgross': 3.25,
#   'budget_2013$': 16.02,
#   'domgross_2013$': 3.47},
#  {'budget': 7.5,
#   'domgross': 32.39,
#   'budget_2013$': 8.14,
#   'domgross_2013$': 35.17},
#  {'budget': 40.0,
#   'domgross': 64.17,
#   'budget_2013$': 43.43,
#   'domgross_2013$': 69.67},
#  {'budget': 200.0,
#   'domgross': 166.11,
#   'budget_2013$': 217.15,
#   'domgross_2013$': 180.35},
#  {'budget': 30.0,
#   'domgross': 31.75,
#   'budget_2013$': 32.57,
#   'domgross_2013$': 34.47},
#  {'budget': 14.0,
#   'domgross': 15.52,
#   'budget_2013$': 15.2,
#   'domgross_2013$': 16.85},
#  {'budget': 7.0,
#   'domgross': 9.23,
#   'budget_2013$': 7.6,
#   'domgross_2013$': 10.02},
#  {'budget': 7.0,
#   'domgross': 9.18,
#   'budget_2013$': 7.6,
#   'domgross_2013$': 9.96},
#  {'budget': 3.2,
#   'domgross': 2.28,
#   'budget_2013$': 3.47,
#   'domgross_2013$': 2.47},
#  {'budget': 9.8,
#   'domgross': 16.04,
#   'budget_2013$': 10.64,
#   'domgross_2013$': 17.42},
#  {'budget': 70.0,
#   'domgross': 0.62,
#   'budget_2013$': 76.0,
#   'domgross_2013$': 0.67},
#  {'budget': 1.0,
#   'domgross': 0.62,
#   'budget_2013$': 1.09,
#   'domgross_2013$': 0.68},
#  {'budget': 15.0,
#   'domgross': 33.86,
#   'budget_2013$': 16.29,
#   'domgross_2013$': 36.77},
#  {'budget': 7.5,
#   'domgross': 12.57,
#   'budget_2013$': 8.14,
#   'domgross_2013$': 13.65},
#  {'budget': 150.0,
#   'domgross': 133.38,
#   'budget_2013$': 162.86,
#   'domgross_2013$': 144.81},
#  {'budget': 20.0,
#   'domgross': 15.99,
#   'budget_2013$': 21.71,
#   'domgross_2013$': 17.36},
#  {'budget': 65.0,
#   'domgross': 19.55,
#   'budget_2013$': 70.57,
#   'domgross_2013$': 21.23},
#  {'budget': 425.0,
#   'domgross': 760.51,
#   'budget_2013$': 461.44,
#   'domgross_2013$': 825.71},
#  {'budget': 21.0,
#   'domgross': 9.45,
#   'budget_2013$': 22.8,
#   'domgross_2013$': 10.26},
#  {'budget': 42.0,
#   'domgross': 60.05,
#   'budget_2013$': 45.6,
#   'domgross_2013$': 65.2},
#  {'budget': 30.0,
#   'domgross': 58.72,
#   'budget_2013$': 32.57,
#   'domgross_2013$': 63.75},
#  {'budget': 8.5,
#   'domgross': 4.44,
#   'budget_2013$': 9.23,
#   'domgross_2013$': 4.83},
#  {'budget': 17.0,
#   'domgross': 27.16,
#   'budget_2013$': 18.46,
#   'domgross_2013$': 29.49},
#  {'budget': 26.0,
#   'domgross': 28.54,
#   'budget_2013$': 28.23,
#   'domgross_2013$': 30.99},
#  {'budget': 20.0,
#   'domgross': 14.36,
#   'budget_2013$': 21.71,
#   'domgross_2013$': 15.59},
#  {'budget': 27.0,
#   'domgross': 13.26,
#   'budget_2013$': 29.31,
#   'domgross_2013$': 14.4},
#  {'budget': 13.0,
#   'domgross': 3.08,
#   'budget_2013$': 14.11,
#   'domgross_2013$': 3.34},
#  {'budget': 100.0,
#   'domgross': 124.87,
#   'budget_2013$': 108.57,
#   'domgross_2013$': 135.58},
#  {'budget': 23.0,
#   'domgross': 6.11,
#   'budget_2013$': 24.97,
#   'domgross_2013$': 6.64},
#  {'budget': 60.0,
#   'domgross': 75.29,
#   'budget_2013$': 65.14,
#   'domgross_2013$': 81.74},
#  {'budget': 20.0,
#   'domgross': 30.1,
#   'budget_2013$': 21.71,
#   'domgross_2013$': 32.68},
#  {'budget': 0.8,
#   'domgross': 0.05,
#   'budget_2013$': 0.87,
#   'domgross_2013$': 0.05},
#  {'budget': 30.0,
#   'domgross': 115.65,
#   'budget_2013$': 32.57,
#   'domgross_2013$': 125.56},
#  {'budget': 30.0,
#   'domgross': 42.1,
#   'budget_2013$': 32.57,
#   'domgross_2013$': 45.71},
#  {'budget': 16.0,
#   'domgross': 0.34,
#   'budget_2013$': 17.37,
#   'domgross_2013$': 0.37},
#  {'budget': 20.0,
#   'domgross': 9.21,
#   'budget_2013$': 21.71,
#   'domgross_2013$': 10.0},
#  {'budget': 40.0,
#   'domgross': 21.0,
#   'budget_2013$': 43.43,
#   'domgross_2013$': 22.8},
#  {'budget': 85.0,
#   'domgross': 155.06,
#   'budget_2013$': 92.29,
#   'domgross_2013$': 168.36},
#  {'budget': 20.0,
#   'domgross': 17.23,
#   'budget_2013$': 21.71,
#   'domgross_2013$': 18.71},
#  {'budget': 3.0,
#   'domgross': 0.37,
#   'budget_2013$': 3.26,
#   'domgross_2013$': 0.41},
#  {'budget': 17.0,
#   'domgross': 65.0,
#   'budget_2013$': 18.46,
#   'domgross_2013$': 70.57},
#  {'budget': 72.5,
#   'domgross': 51.86,
#   'budget_2013$': 78.72,
#   'domgross_2013$': 56.3},
#  {'budget': 150.0,
#   'domgross': 119.44,
#   'budget_2013$': 162.86,
#   'domgross_2013$': 129.68},
#  {'budget': 175.0,
#   'domgross': 150.2,
#   'budget_2013$': 190.0,
#   'domgross_2013$': 163.08},
#  {'budget': 50.0,
#   'domgross': 20.53,
#   'budget_2013$': 54.29,
#   'domgross_2013$': 22.3},
#  {'budget': 7.0,
#   'domgross': 9.18,
#   'budget_2013$': 7.6,
#   'domgross_2013$': 9.96},
#  {'budget': 7.3,
#   'domgross': 1.82,
#   'budget_2013$': 7.93,
#   'domgross_2013$': 1.97},
#  {'budget': 250.0,
#   'domgross': 301.96,
#   'budget_2013$': 271.43,
#   'domgross_2013$': 327.85},
#  {'budget': 40.0,
#   'domgross': 93.95,
#   'budget_2013$': 43.43,
#   'domgross_2013$': 102.01},
#  {'budget': 18.0,
#   'domgross': 0.0,
#   'budget_2013$': 19.54,
#   'domgross_2013$': nan},
#  {'budget': 13.0,
#   'domgross': 2.04,
#   'budget_2013$': 14.11,
#   'domgross_2013$': 2.21},
#  {'budget': 40.0,
#   'domgross': 71.44,
#   'budget_2013$': 43.43,
#   'domgross_2013$': 77.56},
#  {'budget': 90.0,
#   'domgross': 196.57,
#   'budget_2013$': 97.72,
#   'domgross_2013$': 213.43},
#  {'budget': 70.0,
#   'domgross': 120.83,
#   'budget_2013$': 76.0,
#   'domgross_2013$': 131.19},
#  {'budget': 49.0,
#   'domgross': 37.49,
#   'budget_2013$': 53.2,
#   'domgross_2013$': 40.71},
#  {'budget': 85.0,
#   'domgross': 112.74,
#   'budget_2013$': 92.29,
#   'domgross_2013$': 122.4},
#  {'budget': 16.0,
#   'domgross': 16.2,
#   'budget_2013$': 17.37,
#   'domgross_2013$': 17.59},
#  {'budget': 40.0,
#   'domgross': 94.13,
#   'budget_2013$': 43.43,
#   'domgross_2013$': 102.19},
#  {'budget': 50.0,
#   'domgross': 79.96,
#   'budget_2013$': 54.29,
#   'domgross_2013$': 86.81},
#  {'budget': 53.0,
#   'domgross': 73.36,
#   'budget_2013$': 57.54,
#   'domgross_2013$': 79.65},
#  {'budget': 4.5,
#   'domgross': 0.28,
#   'budget_2013$': 4.89,
#   'domgross_2013$': 0.31},
#  {'budget': 42.0,
#   'domgross': 1.26,
#   'budget_2013$': 45.6,
#   'domgross_2013$': 1.37},
#  {'budget': 175.0,
#   'domgross': 198.35,
#   'budget_2013$': 190.0,
#   'domgross_2013$': 215.36},
#  {'budget': 5.0,
#   'domgross': 5.01,
#   'budget_2013$': 5.43,
#   'domgross_2013$': 5.44},
#  {'budget': 7.0,
#   'domgross': 1.11,
#   'budget_2013$': 7.6,
#   'domgross_2013$': 1.21},
#  {'budget': 14.0,
#   'domgross': 51.55,
#   'budget_2013$': 15.2,
#   'domgross_2013$': 55.97},
#  {'budget': 27.5,
#   'domgross': 49.2,
#   'budget_2013$': 29.86,
#   'domgross_2013$': 53.42},
#  {'budget': 80.0,
#   'domgross': 19.68,
#   'budget_2013$': 86.86,
#   'domgross_2013$': 21.36},
#  {'budget': 50.0,
#   'domgross': 38.12,
#   'budget_2013$': 54.29,
#   'domgross_2013$': 41.39},
#  {'budget': 1.9,
#   'domgross': 1.45,
#   'budget_2013$': 2.06,
#   'domgross_2013$': 1.57},
#  {'budget': 12.0,
#   'domgross': 0.55,
#   'budget_2013$': 13.03,
#   'domgross_2013$': 0.6},
#  {'budget': 4.3,
#   'domgross': 0.2,
#   'budget_2013$': 4.67,
#   'domgross_2013$': 0.22},
#  {'budget': 40.0,
#   'domgross': 10.33,
#   'budget_2013$': 43.43,
#   'domgross_2013$': 11.22},
#  {'budget': 6.6, 'domgross': 0.0, 'budget_2013$': 7.17, 'domgross_2013$': 0.0},
#  {'budget': 60.0,
#   'domgross': 42.19,
#   'budget_2013$': 65.14,
#   'domgross_2013$': 45.81},
#  {'budget': 10.0,
#   'domgross': 47.57,
#   'budget_2013$': 10.86,
#   'domgross_2013$': 51.64},
#  {'budget': 102.5,
#   'domgross': 97.1,
#   'budget_2013$': 111.29,
#   'domgross_2013$': 105.43},
#  {'budget': 38.0,
#   'domgross': 31.81,
#   'budget_2013$': 41.26,
#   'domgross_2013$': 34.54},
#  {'budget': 90.0,
#   'domgross': 209.03,
#   'budget_2013$': 97.72,
#   'domgross_2013$': 226.95},
#  {'budget': 30.0,
#   'domgross': 17.01,
#   'budget_2013$': 32.57,
#   'domgross_2013$': 18.47},
#  {'budget': 140.0,
#   'domgross': 257.73,
#   'budget_2013$': 152.0,
#   'domgross_2013$': 279.83},
#  {'budget': 60.0,
#   'domgross': 37.02,
#   'budget_2013$': 65.14,
#   'domgross_2013$': 40.19},
#  {'budget': 80.0,
#   'domgross': 38.58,
#   'budget_2013$': 86.86,
#   'domgross_2013$': 41.89},
#  {'budget': 200.0,
#   'domgross': 125.32,
#   'budget_2013$': 217.15,
#   'domgross_2013$': 136.07},
#  {'budget': 35.0,
#   'domgross': 255.96,
#   'budget_2013$': 38.0,
#   'domgross_2013$': 277.9},
#  {'budget': 50.0,
#   'domgross': 8.02,
#   'budget_2013$': 54.29,
#   'domgross_2013$': 8.7},
#  {'budget': 8.0,
#   'domgross': 10.27,
#   'budget_2013$': 8.69,
#   'domgross_2013$': 11.15},
# ...
#   'budget_2013$': 25.43,
#   'domgross_2013$': 5.08},
#  {'budget': 55.0,
#   'domgross': 25.86,
#   'budget_2013$': 65.62,
#   'domgross_2013$': 30.85},
#  {'budget': 30.0,
#   'domgross': 20.04,
#   'budget_2013$': 35.79,
#   'domgross_2013$': 23.91},
#  {'budget': 150.0,
#   'domgross': 205.34,
#   'budget_2013$': 178.95,
#   'domgross_2013$': 244.98},
#  {'budget': 25.0,
#   'domgross': 36.35,
#   'budget_2013$': 29.83,
#   'domgross_2013$': 43.37},
#  {'budget': 80.0,
#   'domgross': 63.31,
#   'budget_2013$': 95.44,
#   'domgross_2013$': 75.53},
#  {'budget': 25.0,
#   'domgross': 2.41,
#   'budget_2013$': 29.83,
#   'domgross_2013$': 2.87},
#  {'budget': 20.0,
#   'domgross': 46.75,
#   'budget_2013$': 23.86,
#   'domgross_2013$': 55.78},
#  {'budget': 2.9,
#   'domgross': 3.13,
#   'budget_2013$': 3.46,
#   'domgross_2013$': 3.73},
#  {'budget': 0.45,
#   'domgross': 2.08,
#   'budget_2013$': 0.54,
#   'domgross_2013$': 2.48},
#  {'budget': 13.9,
#   'domgross': 83.04,
#   'budget_2013$': 16.58,
#   'domgross_2013$': 99.07},
#  {'budget': 7.0,
#   'domgross': 28.75,
#   'budget_2013$': 8.35,
#   'domgross_2013$': 34.3},
#  {'budget': 150.0,
#   'domgross': 206.46,
#   'budget_2013$': 178.95,
#   'domgross_2013$': 246.31},
#  {'budget': 4.5,
#   'domgross': 0.21,
#   'budget_2013$': 5.37,
#   'domgross_2013$': 0.25},
#  {'budget': 88.0,
#   'domgross': 61.65,
#   'budget_2013$': 104.99,
#   'domgross_2013$': 73.55},
#  {'budget': 45.0,
#   'domgross': 67.26,
#   'budget_2013$': 53.69,
#   'domgross_2013$': 80.25},
#  {'budget': 75.0,
#   'domgross': 75.98,
#   'budget_2013$': 89.48,
#   'domgross_2013$': 90.64},
#  {'budget': 0.45,
#   'domgross': 0.38,
#   'budget_2013$': 0.54,
#   'domgross_2013$': 0.45},
#  {'budget': 30.0,
#   'domgross': 53.36,
#   'budget_2013$': 35.79,
#   'domgross_2013$': 63.66},
#  {'budget': 35.0,
#   'domgross': 19.29,
#   'budget_2013$': 41.76,
#   'domgross_2013$': 23.02},
#  {'budget': 43.0,
#   'domgross': 24.54,
#   'budget_2013$': 51.3,
#   'domgross_2013$': 29.27},
#  {'budget': 60.0,
#   'domgross': 25.47,
#   'budget_2013$': 71.58,
#   'domgross_2013$': 30.39},
#  {'budget': 8.0,
#   'domgross': 0.02,
#   'budget_2013$': 9.54,
#   'domgross_2013$': 0.03},
#  {'budget': 50.0,
#   'domgross': 10.17,
#   'budget_2013$': 59.65,
#   'domgross_2013$': 12.13},
#  {'budget': 70.0,
#   'domgross': 28.21,
#   'budget_2013$': 83.51,
#   'domgross_2013$': 33.66},
#  {'budget': 87.5,
#   'domgross': 154.7,
#   'budget_2013$': 104.39,
#   'domgross_2013$': 184.56},
#  {'budget': 55.0,
#   'domgross': 89.71,
#   'budget_2013$': 65.62,
#   'domgross_2013$': 107.02},
#  {'budget': 140.0,
#   'domgross': 110.55,
#   'budget_2013$': 167.02,
#   'domgross_2013$': 131.89},
#  {'budget': 7.0,
#   'domgross': 31.5,
#   'budget_2013$': 8.35,
#   'domgross_2013$': 37.58},
#  {'budget': 0.95,
#   'domgross': 1.02,
#   'budget_2013$': 1.13,
#   'domgross_2013$': 1.22},
#  {'budget': 150.0,
#   'domgross': 290.01,
#   'budget_2013$': 178.95,
#   'domgross_2013$': 346.0},
#  {'budget': 50.0,
#   'domgross': 66.01,
#   'budget_2013$': 59.65,
#   'domgross_2013$': 78.75},
#  {'budget': 25.0,
#   'domgross': 51.1,
#   'budget_2013$': 29.83,
#   'domgross_2013$': 60.96},
#  {'budget': 55.0,
#   'domgross': 177.78,
#   'budget_2013$': 65.62,
#   'domgross_2013$': 212.1},
#  {'budget': 17.5,
#   'domgross': 51.39,
#   'budget_2013$': 20.88,
#   'domgross_2013$': 61.31},
#  {'budget': 4.8,
#   'domgross': 47.33,
#   'budget_2013$': 5.73,
#   'domgross_2013$': 56.46},
#  {'budget': 2.8,
#   'domgross': 22.2,
#   'budget_2013$': 3.34,
#   'domgross_2013$': 26.49},
#  {'budget': 25.0,
#   'domgross': 24.38,
#   'budget_2013$': 29.83,
#   'domgross_2013$': 29.09},
#  {'budget': 72.0,
#   'domgross': 62.65,
#   'budget_2013$': 85.9,
#   'domgross_2013$': 74.74},
#  {'budget': 1.0,
#   'domgross': 2.68,
#   'budget_2013$': 1.19,
#   'domgross_2013$': 3.19},
#  {'budget': 58.0,
#   'domgross': 48.32,
#   'budget_2013$': 69.2,
#   'domgross_2013$': 57.65},
#  {'budget': 207.0,
#   'domgross': 218.08,
#   'budget_2013$': 246.96,
#   'domgross_2013$': 260.18},
#  {'budget': 110.0,
#   'domgross': 47.4,
#   'budget_2013$': 131.23,
#   'domgross_2013$': 56.55},
#  {'budget': 15.0,
#   'domgross': 4.24,
#   'budget_2013$': 17.9,
#   'domgross_2013$': 5.05},
#  {'budget': 42.0,
#   'domgross': 24.15,
#   'budget_2013$': 50.11,
#   'domgross_2013$': 28.81},
#  {'budget': 75.0,
#   'domgross': 193.6,
#   'budget_2013$': 89.48,
#   'domgross_2013$': 230.97},
#  {'budget': 50.0,
#   'domgross': 19.7,
#   'budget_2013$': 59.65,
#   'domgross_2013$': 23.5},
#  {'budget': 15.0,
#   'domgross': 23.09,
#   'budget_2013$': 17.9,
#   'domgross_2013$': 27.55},
#  {'budget': 2.0,
#   'domgross': 3.89,
#   'budget_2013$': 2.39,
#   'domgross_2013$': 4.64},
#  {'budget': 85.0,
#   'domgross': 57.01,
#   'budget_2013$': 101.41,
#   'domgross_2013$': 68.02},
#  {'budget': 4.0,
#   'domgross': 0.86,
#   'budget_2013$': 4.77,
#   'domgross_2013$': 1.03},
#  {'budget': 60.0,
#   'domgross': 48.48,
#   'budget_2013$': 71.58,
#   'domgross_2013$': 57.84},
#  {'budget': 110.0,
#   'domgross': 186.34,
#   'budget_2013$': 131.23,
#   'domgross_2013$': 222.31},
#  {'budget': 75.0,
#   'domgross': 47.38,
#   'budget_2013$': 89.48,
#   'domgross_2013$': 56.52},
#  {'budget': 30.0,
#   'domgross': 18.32,
#   'budget_2013$': 35.79,
#   'domgross_2013$': 21.86},
#  {'budget': 65.0,
#   'domgross': 2.07,
#   'budget_2013$': 77.55,
#   'domgross_2013$': 2.47},
#  {'budget': 28.0,
#   'domgross': 38.37,
#   'budget_2013$': 33.4,
#   'domgross_2013$': 45.78},
#  {'budget': 20.0,
#   'domgross': 7.54,
#   'budget_2013$': 23.86,
#   'domgross_2013$': 8.99},
#  {'budget': 26.0,
#   'domgross': 57.89,
#   'budget_2013$': 31.02,
#   'domgross_2013$': 69.07},
#  {'budget': 40.0,
#   'domgross': 29.08,
#   'budget_2013$': 47.72,
#   'domgross_2013$': 34.69},
#  {'budget': 80.0,
#   'domgross': 128.2,
#   'budget_2013$': 95.44,
#   'domgross_2013$': 152.95},
#  {'budget': 5.0,
#   'domgross': 87.03,
#   'budget_2013$': 5.97,
#   'domgross_2013$': 103.82},
#  {'budget': 39.0,
#   'domgross': 25.51,
#   'budget_2013$': 46.53,
#   'domgross_2013$': 30.44},
#  {'budget': 7.5,
#   'domgross': 10.28,
#   'budget_2013$': 8.95,
#   'domgross_2013$': 12.27},
#  {'budget': 40.0,
#   'domgross': 74.1,
#   'budget_2013$': 47.72,
#   'domgross_2013$': 88.41},
#  {'budget': 0.3,
#   'domgross': 0.03,
#   'budget_2013$': 0.36,
#   'domgross_2013$': 0.04},
#  {'budget': 60.0,
#   'domgross': 63.94,
#   'budget_2013$': 71.58,
#   'domgross_2013$': 76.28},
#  {'budget': 100.0,
#   'domgross': 17.02,
#   'budget_2013$': 119.3,
#   'domgross_2013$': 20.3},
#  {'budget': 115.0,
#   'domgross': 380.27,
#   'budget_2013$': 137.2,
#   'domgross_2013$': 453.68},
#  {'budget': 138.0,
#   'domgross': 32.12,
#   'budget_2013$': 164.64,
#   'domgross_2013$': 38.32},
#  {'budget': 2.0,
#   'domgross': 2.07,
#   'budget_2013$': 2.39,
#   'domgross_2013$': 2.47},
#  {'budget': 7.5,
#   'domgross': 24.79,
#   'budget_2013$': 8.95,
#   'domgross_2013$': 29.58},
#  {'budget': 26.0,
#   'domgross': 109.45,
#   'budget_2013$': 31.02,
#   'domgross_2013$': 130.58},
#  {'budget': 50.0,
#   'domgross': 39.18,
#   'budget_2013$': 59.65,
#   'domgross_2013$': 46.74},
#  {'budget': 18.5,
#   'domgross': 65.23,
#   'budget_2013$': 22.07,
#   'domgross_2013$': 77.83},
#  {'budget': 1.5,
#   'domgross': 0.71,
#   'budget_2013$': 1.79,
#   'domgross_2013$': 0.85},
#  {'budget': 180.0,
#   'domgross': 291.71,
#   'budget_2013$': 214.75,
#   'domgross_2013$': 348.02},
#  {'budget': 25.5,
#   'domgross': 33.58,
#   'budget_2013$': 30.42,
#   'domgross_2013$': 40.06},
#  {'budget': 7.0,
#   'domgross': 26.02,
#   'budget_2013$': 8.35,
#   'domgross_2013$': 31.05},
#  {'budget': 7.0,
#   'domgross': 17.04,
#   'budget_2013$': 8.35,
#   'domgross_2013$': 20.34},
#  {'budget': 18.0,
#   'domgross': 75.07,
#   'budget_2013$': 21.47,
#   'domgross_2013$': 89.56},
#  {'budget': 18.0,
#   'domgross': 29.51,
#   'budget_2013$': 21.47,
#   'domgross_2013$': 35.21},
#  {'budget': 45.0,
#   'domgross': 51.02,
#   'budget_2013$': 53.69,
#   'domgross_2013$': 60.87},
#  {'budget': 120.0,
#   'domgross': 35.82,
#   'budget_2013$': 143.16,
#   'domgross_2013$': 42.73},
#  {'budget': 28.5,
#   'domgross': 6.3,
#   'budget_2013$': 34.0,
#   'domgross_2013$': 7.52},
#  {'budget': 80.0,
#   'domgross': 45.58,
#   'budget_2013$': 95.44,
#   'domgross_2013$': 54.37},
#  {'budget': 30.0,
#   'domgross': 12.71,
#   'budget_2013$': 35.79,
#   'domgross_2013$': 15.17},
#  {'budget': 50.0,
#   'domgross': 75.94,
#   'budget_2013$': 59.65,
#   'domgross_2013$': 90.6},
#  {'budget': 40.0,
#   'domgross': 47.91,
#   'budget_2013$': 47.72,
#   'domgross_2013$': 57.16},
#  {'budget': 1.5,
#   'domgross': 7.37,
#   'budget_2013$': 1.79,
#   'domgross_2013$': 8.8},
#  {'budget': 15.0,
#   'domgross': 31.73,
#   'budget_2013$': 17.9,
#   'domgross_2013$': 37.85},
#  {'budget': 1.0,
#   'domgross': 9.02,
#   'budget_2013$': 1.19,
#   'domgross_2013$': 10.76},
#  {'budget': 4.75,
#   'domgross': 1.25,
#   'budget_2013$': 5.67,
#   'domgross_2013$': 1.5},
#  {'budget': 50.0,
#   'domgross': 70.51,
#   'budget_2013$': 59.65,
#   'domgross_2013$': 84.12},
#  {'budget': 1.12,
#   'domgross': 16.12,
#   'budget_2013$': 1.34,
#   'domgross_2013$': 19.24},
#  {'budget': 29.0,
#   'domgross': 119.52,
#   'budget_2013$': 34.6,
#   'domgross_2013$': 142.59},
#  {'budget': 132.0,
#   'domgross': 234.28,
#   'budget_2013$': 157.48,
#   'domgross_2013$': 279.5},
#  {'budget': 3.0,
#   'domgross': 5.53,
#   'budget_2013$': 3.58,
#   'domgross_2013$': 6.6},
#  {'budget': 10.0,
#   'domgross': 56.09,
#   'budget_2013$': 11.93,
#   'domgross_2013$': 66.92},
#  {'budget': 45.0,
#   'domgross': 53.36,
#   'budget_2013$': 53.69,
#   'domgross_2013$': 63.66},
#  {'budget': 65.0,
#   'domgross': 28.05,
#   'budget_2013$': 77.55,
#   'domgross_2013$': 33.46},
#  {'budget': 30.0,
#   'domgross': 57.14,
#   'budget_2013$': 37.0,
#   'domgross_2013$': 70.46},
#  {'budget': 12.0,
#   'domgross': 1.44,
#   'budget_2013$': 14.8,
#   'domgross_2013$': 1.78},
#  {'budget': 75.0,
#   'domgross': 120.78,
#   'budget_2013$': 92.49,
#   'domgross_2013$': 148.94},
#  {'budget': 19.0,
#   'domgross': 51.44,
#   'budget_2013$': 23.43,
#   'domgross_2013$': 63.43},
#  {'budget': 6.5,
#   'domgross': 1.03,
#   'budget_2013$': 8.02,
#   'domgross_2013$': 1.27},
#  {'budget': 55.0,
#   'domgross': 6.17,
#   'budget_2013$': 67.83,
#   'domgross_2013$': 7.61},
#  {'budget': 25.0,
#   'domgross': 84.14,
#   'budget_2013$': 30.83,
#   'domgross_2013$': 103.76},
#  {'budget': 110.0,
#   'domgross': 24.0,
#   'budget_2013$': 135.65,
#   'domgross_2013$': 29.6},
#  {'budget': 70.0,
#   'domgross': 80.28,
#   'budget_2013$': 86.32,
#   'domgross_2013$': 99.0},
#  {'budget': 15.0,
#   'domgross': 1.2,
#   'budget_2013$': 18.5,
#   'domgross_2013$': 1.48},
#  {'budget': 2.0,
#   'domgross': 5.79,
#   'budget_2013$': 2.47,
#   'domgross_2013$': 7.14},
#  {'budget': 50.0,
#   'domgross': 40.2,
#   'budget_2013$': 61.66,
#   'domgross_2013$': 49.58},
#  {'budget': 100.0,
#   'domgross': 40.2,
#   'budget_2013$': 123.32,
#   'domgross_2013$': 49.58},
#  {'budget': 45.0,
#   'domgross': 32.0,
#   'budget_2013$': 55.49,
#   'domgross_2013$': 39.47},
#  {'budget': 35.0,
#   'domgross': 33.99,
#   'budget_2013$': 43.16,
#   'domgross_2013$': 41.91},
#  {'budget': 60.0,
#   'domgross': 100.17,
#   'budget_2013$': 73.99,
#   'domgross_2013$': 123.53},
#  {'budget': 20.0,
#   'domgross': 8.05,
#   'budget_2013$': 24.66,
#   'domgross_2013$': 9.92},
#  {'budget': 7.3,
#   'domgross': 55.33,
#   'budget_2013$': 9.01,
#   'domgross_2013$': 68.24},
#  {'budget': 3.5,
#   'domgross': 0.1,
#   'budget_2013$': 4.32,
#   'domgross_2013$': 0.12},
#  {'budget': 28.0,
#   'domgross': 58.99,
#   'budget_2013$': 34.53,
#   'domgross_2013$': 72.75},
#  {'budget': 30.0,
#   'domgross': 114.33,
#   'budget_2013$': 37.0,
#   'domgross_2013$': 140.99},
#  {'budget': 35.0,
#   'domgross': 22.91,
#   'budget_2013$': 43.16,
#   'domgross_2013$': 28.26},
#  {'budget': 20.0,
#   'domgross': 34.37,
#   'budget_2013$': 24.66,
#   'domgross_2013$': 42.38},
#  {'budget': 10.0,
#   'domgross': 0.07,
#   'budget_2013$': 12.33,
#   'domgross_2013$': 0.09},
#  {'budget': 25.0,
#   'domgross': 51.68,
#   'budget_2013$': 30.83,
#   'domgross_2013$': 63.73},
#  {'budget': 75.0,
#   'domgross': 21.01,
#   'budget_2013$': 92.49,
#   'domgross_2013$': 25.91},
#  {'budget': 2.5,
#   'domgross': 26.78,
#   'budget_2013$': 3.08,
#   'domgross_2013$': 33.03},
#  {'budget': 9.0,
#   'domgross': 18.23,
#   'budget_2013$': 11.1,
#   'domgross_2013$': 22.48},
#  {'budget': 130.0,
#   'domgross': 249.54,
#   'budget_2013$': 160.32,
#   'domgross_2013$': 307.73},
#  {'budget': 60.0,
#   'domgross': 59.62,
#   'budget_2013$': 73.99,
#   'domgross_2013$': 73.53},
#  {'budget': 110.0,
#   'domgross': 50.03,
#   'budget_2013$': 135.65,
#   'domgross_2013$': 61.69},
#  {'budget': 22.0,
#   'domgross': 12.78,
#   'budget_2013$': 27.13,
#   'domgross_2013$': 15.77},
#  {'budget': 105.0,
#   'domgross': 144.8,
#   'budget_2013$': 129.49,
#   'domgross_2013$': 178.57},
#  {'budget': 26.0,
#   'domgross': 45.49,
#   'budget_2013$': 32.06,
#   'domgross_2013$': 56.1},
#  {'budget': 11.0,
#   'domgross': 10.21,
#   'budget_2013$': 13.57,
#   'domgross_2013$': 12.6},
#  {'budget': 20.0,
#   'domgross': 17.1,
#   'budget_2013$': 24.66,
#   'domgross_2013$': 21.09},
#  {'budget': 6.5,
#   'domgross': 2.34,
#   'budget_2013$': 8.02,
#   'domgross_2013$': 2.89},
#  {'budget': 100.0,
#   'domgross': 118.63,
#   'budget_2013$': 123.32,
#   'domgross_2013$': 146.29},
#  {'budget': 3.2,
#   'domgross': 6.53,
#   'budget_2013$': 3.95,
#   'domgross_2013$': 8.05},
#  {'budget': 18.0,
#   'domgross': 86.05,
#   'budget_2013$': 22.2,
#   'domgross_2013$': 106.11},
#  {'budget': 30.0,
#   'domgross': 100.49,
#   'budget_2013$': 37.0,
#   'domgross_2013$': 123.93},
#  {'budget': 28.0,
#   'domgross': 64.38,
#   'budget_2013$': 34.53,
#   'domgross_2013$': 79.39},
#  {'budget': 1.7, 'domgross': 1.0, 'budget_2013$': 2.1, 'domgross_2013$': 1.23},
#  {'budget': 0.4,
#   'domgross': 44.54,
#   'budget_2013$': 0.49,
#   'domgross_2013$': 54.93},
#  {'budget': 40.0,
#   'domgross': 14.02,
#   'budget_2013$': 49.33,
#   'domgross_2013$': 17.29},
#  {'budget': 0.01,
#   'domgross': 0.42,
#   'budget_2013$': 0.01,
#   'domgross_2013$': 0.52},
#  {'budget': 50.0,
#   'domgross': 37.49,
#   'budget_2013$': 61.66,
#   'domgross_2013$': 46.23},
#  {'budget': 40.0,
#   'domgross': 75.31,
#   'budget_2013$': 49.33,
#   'domgross_2013$': 92.87},
#  {'budget': 50.0,
#   'domgross': 50.74,
#   'budget_2013$': 61.66,
#   'domgross_2013$': 62.57},
#  {'budget': 5.0,
#   'domgross': 8.89,
#   'budget_2013$': 6.17,
#   'domgross_2013$': 10.96},
#  {'budget': 1.2,
#   'domgross': 55.19,
#   'budget_2013$': 1.48,
#   'domgross_2013$': 68.05},
#  {'budget': 40.0,
#   'domgross': 47.96,
#   'budget_2013$': 49.33,
#   'domgross_2013$': 59.14},
#  {'budget': 75.0,
#   'domgross': 161.41,
#   'budget_2013$': 92.49,
#   'domgross_2013$': 199.05},
#  {'budget': 5.0,
#   'domgross': 13.54,
#   'budget_2013$': 6.17,
#   'domgross_2013$': 16.7},
#  {'budget': 70.0,
#   'domgross': 441.23,
#   'budget_2013$': 86.32,
#   'domgross_2013$': 544.12},
#  {'budget': 17.0,
#   'domgross': 71.5,
#   'budget_2013$': 20.96,
#   'domgross_2013$': 88.18},
#  {'budget': 70.0,
#   'domgross': 37.76,
#   'budget_2013$': 86.32,
#   'domgross_2013$': 46.57},
#  {'budget': 75.0,
#   'domgross': 42.04,
#   'budget_2013$': 92.49,
#   'domgross_2013$': 51.85},
#  {'budget': 200.0,
#   'domgross': 373.52,
#   'budget_2013$': 246.64,
#   'domgross_2013$': 460.63},
#  {'budget': 20.0,
#   'domgross': 32.77,
#   'budget_2013$': 24.66,
#   'domgross_2013$': 40.42},
#  {'budget': 110.0,
#   'domgross': 102.61,
#   'budget_2013$': 135.65,
#   'domgross_2013$': 126.54},
#  {'budget': 85.0,
#   'domgross': 176.09,
#   'budget_2013$': 104.82,
#   'domgross_2013$': 217.15},
#  {'budget': 13.0,
#   'domgross': 57.92,
#   'budget_2013$': 16.03,
#   'domgross_2013$': 71.43},
#  {'budget': 120.0,
#   'domgross': 57.71,
#   'budget_2013$': 147.98,
#   'domgross_2013$': 71.17},
#  {'budget': 125.0,
#   'domgross': 186.74,
#   'budget_2013$': 154.15,
#   'domgross_2013$': 230.29},
#  {'budget': 10.0,
#   'domgross': 110.36,
#   'budget_2013$': 12.33,
#   'domgross_2013$': 136.09},
#  {'budget': 92.0,
#   'domgross': 261.44,
#   'budget_2013$': 113.45,
#   'domgross_2013$': 322.41},
#  {'budget': 50.0,
#   'domgross': 24.01,
#   'budget_2013$': 61.66,
#   'domgross_2013$': 29.6},
#  {'budget': 30.0,
#   'domgross': 81.0,
#   'budget_2013$': 37.0,
#   'domgross_2013$': 99.89},
#  {'budget': 55.0,
#   'domgross': 51.23,
#   'budget_2013$': 67.83,
#   'domgross_2013$': 63.17},
#  {'budget': 170.0,
#   'domgross': 194.95,
#   'budget_2013$': 209.64,
#   'domgross_2013$': 240.41},
#  {'budget': 45.0,
#   'domgross': 95.15,
#   'budget_2013$': 55.49,
#   'domgross_2013$': 117.34},
#  {'budget': 100.0,
#   'domgross': 59.48,
#   'budget_2013$': 123.32,
#   'domgross_2013$': 73.34},
#  {'budget': 75.0,
#   'domgross': 77.07,
#   'budget_2013$': 92.49,
#   'domgross_2013$': 95.05},
#  ...]

# %% [markdown]
# Ok, now that we have a function to scale down our movies, lets `map` through all of our `parsed_movies` to return a list of `scaled_movies`.

# %%
def scale_down_movies(movies):
    pass

# %%
first_ten_movies = parsed_movies[0:10]
first_ten_scaled = scale_down_movies(first_ten_movies) or []
first_ten_scaled[-2:]
#[{'year': 2013,
#  'imdb': 'tt1814621',
#  'title': 'Admission',
#  'test': 'ok',
#  'clean_test': 'ok',
#  'binary': 'PASS',
#  'budget': 13.0,
#  'domgross': 18.01,
#  'intgross': 18.01,
#  'code': '2013PASS',
#  'budget_2013$': 13.0,
#  'domgross_2013$': 18.01,
#  'intgross_2013$': 18.01,
#  'period code': 1.0,
#  'decade code': 1.0},
# {'year': 2013,
#  'imdb': 'tt1815862',
#  'title': 'After Earth',
#  'test': 'notalk',
#  'clean_test': 'notalk',
#  'binary': 'FAIL',
#  'budget': 130.0,
#  'domgross': 60.52,
#  'intgross': 244.37,
#  'code': '2013FAIL',
#  'budget_2013$': 130.0,
#  'domgross_2013$': 60.52,
#  'intgross_2013$': 244.37,
#  'period code': 1.0,
#  'decade code': 1.0}]

# %%
scaled_movies = scale_down_movies(parsed_movies) or []

# %% [markdown]
# #### 3. Continue exploring the data
#
# Now let's plot our dataset using Plotly to see how much money a movie made domestically in 2013 dollars given a budget in 2013 dollars. Create a trace called `revenues_per_budgets_trace` that plots this data.
#
# > To do so, set `budget_2013$` as the $x$ values, and the `domgross_2013$` as the $y$ values. Set the text of the trace equal to a list of the movie titles, so that we can see which movie is associated with each point. All of the data should be coming from our `scaled_movies` variable.

# %%
budgets = list(map(lambda movie: movie['budget_2013$'], scaled_movies))
domestic_revenues = list(map(lambda movie: movie['domgross_2013$'], scaled_movies))
titles = list(map(lambda movie: movie['title'], scaled_movies))

# %% [markdown]
# We'll check the first ten values of the `budgets`, `domestic_revenues`, and `titles` lists, but your trace should have an element for each of the `scaled_movies` in the dataset.

# %%
budgets[0:10] # [13.0, 45.66, 20.0, 61.0, 40.0, 225.0, 92.0, 12.0, 13.0, 130.0]

# %%
domestic_revenues[0:10] # [25.68, 13.61, 53.11, 75.61, 95.02, 38.36, 67.35, 15.32, 18.01, 60.52]

# %%
titles[0:10] 
# ['21 &amp; Over',  'Dredd 3D', '12 Years a Slave', '2 Guns', '42', '47 Ronin',  'A Good Day to Die Hard',
# 'About Time',  'Admission',  'After Earth']

# %% [markdown]
# Once we have lists of these values, we are ready to create a trace. The following code creates a trace with the x values set as the `budgets`, the y values set as the `domestic_revenues`, and the text set as each of the movie `titles`.

# %%
from graph import trace_values
revenues_per_budgets_trace = trace_values(budgets, domestic_revenues, text = titles)

# %% [markdown]
# > Once we have written the above code, we'll be ready to plot this data. Press shift + enter on the code below and you should see all movies in a graph.

# %%
from graph import plot
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

plot([revenues_per_budgets_trace])

# %% [markdown]
# Look at that one datapoint that earned well over 1.5 billion dollars.  What movie is that?

# %% [markdown]
# Write a function called `highest_domestic_gross` that finds the highest grossing movie given a list of movies.

# %%
def highest_domestic_gross(movies):
    pass

# %%
max_movie = highest_domestic_gross(scaled_movies) or {'title': 'some non movie'}
max_movie['title'] # 'Star Wars'

# %% [markdown]
# Huh, well we should've known.  Now let's zoom in on our dataset so that our plot no longer expands for just a few of the outliers. We will set the x-axis of our plot to go from zero to 300 million dollars, and the y-axis of our plot to go from zero to one billion dollars.

# %%
from graph import build_layout
revenues_per_budgets_trace = trace_values(budgets, domestic_revenues, text = titles)
revenues_layout = build_layout(x_range = [0, 300], y_range = [0, 1000])
plot([revenues_per_budgets_trace], revenues_layout)

# %% [markdown]
# Ok, well at least we have a closer look at our data.  We still see Titanic up in the top right corner.

# %% [markdown]
# ### Building our models

# %% [markdown]
# Ok, now that we have collected and explored this data, our company hired an outside consultant to create a model that predicts revenue for us. The consultant provided us with the following:
#
# $$R(x) = 1.5*budget + 10$$
#
# * where $x$ is a movie's budget in 2013 dollars, and $R(x)$ is the expected revenue in 2013 dollars.
#
# Write a function called `outside_consultant_predicted_revenue` that, provided a budget, returns the expected revenue according to the outside consultant's formula.

# %%
def outside_consultant_predicted_revenue(budget):
    pass

# %% [markdown]
# Let's plot the consultant estimated revenue to see visually if his estimates line up.  We will call this trace `external consultant estimate`.

# %%
budgets = list(map(lambda movie: movie['budget_2013$'], scaled_movies))
domestic_revenues = list(map(lambda movie: movie['domgross_2013$'], scaled_movies))
titles = list(map(lambda movie: movie['title'], scaled_movies))

consultant_estimated_revenues = list(map(lambda budget: outside_consultant_predicted_revenue(budget),budgets))
consultant_estimated_revenues_trace = trace_values(budgets, consultant_estimated_revenues, mode='lines', name = 'external consultant estimate')

# %%
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

from graph import trace_values, m_b_trace, plot

plot([revenues_per_budgets_trace, consultant_estimated_revenues_trace], revenues_layout)

# %% [markdown]
# Overall, the model doesn't look too bad.  However, we can calculate the RSS to quantify how accurate his model really is.
#
# Let's write a method called `error_for_consultant_model` which takes in a budget of a movie in our dataset, and returns the difference between the movie's gross domestic revenue in 2013 dollars, and the prediction from the consultant's model.

# %%
def error_for_consultant_model(movie):
    pass

# %%
american_hustle = {'binary': 'PASS', 'budget': 40.0, 'budget_2013$': 40.0, 'clean_test': 'ok',
         'code': '2013PASS', 'decade code': 1.0, 'domgross': 148.43, 'domgross_2013$': 148.43, 'imdb': 'tt1800241',
         'intgross': 249.48, 'intgross_2013$': 249.48, 'period code': 1.0, 'test': 'ok-disagree',
         'title': 'American Hustle', 'year': 2013}
error_for_consultant_model(american_hustle) # 78.43

# %% [markdown]
# Once we have written a formula that calculates the error for the consultant's model provided a budget, we can write a method that calculates the RSS for the consultant's model.  When we move on to compare our consultant's model with others, we'll then have a metric for comparison.

# %%
def rss_consultant(movies):
    pass

# %%
rss_consultant(scaled_movies) # 23234357.68

# %% [markdown]
# Ok, we'll find out if this number is any good later, but for right now let's just say that our RSS is good enough.  Use the derivative to write a function that provided a budget, returns the $\frac{\Delta R}{\Delta x}$ according to the consultant's model.  Remember that our consultant's model is $R(x) = 1.5x + 10$ where $x$ is a budget, and $R(x)$ is an expected revenue.

# %% [markdown]
# ### A new model

# %% [markdown]
# Now imagine a data scientist in your company wants to take a crack at his own model for predicting a movie's revenue.  The data scientist notices, that in general, movies tend to make more money per year.

# %%
from graph import build_layout
years = list(map(lambda movie: movie['year'],movies))
years_and_revenues = trace_values(years, domestic_revenues, text = titles)
years_layout = build_layout(y_range = [0, 550])
plot([years_and_revenues], years_layout)

# %% [markdown]
# So the data scientist comes up with a new model, to indicate a movie's expected revenue is 1.5 million for every year after 1965 plus 1.1 times the movie's budget.  Write a function called `revenue_with_year` that takes as arguments `budget` and `year` and returns expected revenue.

# %%
def revenue_with_year(budget, year):
    pass

# %%
revenue_with_year(25, 1997) # 75.5
revenue_with_year(40, 1983) # 71.0

# %% [markdown]
# Notice that this model has **two variables**, the budget and year, and therefore is not a line function.  Let's compare these models by plotting the actual revenues and budgets, the prior `external consultant estimate` line trace, and the `internal consultant estimate` based upon this model's estimates.  Since this model doesn't produce a line, we will set the mode for `internal_consultant_estimated_trace` to 'markers'.

# %%
budgets = list(map(lambda movie: movie['budget_2013$'], scaled_movies))
domestic_revenues = list(map(lambda movie: movie['domgross_2013$'], scaled_movies))
titles = list(map(lambda movie: movie['title'], scaled_movies))

internal_consultant_estimated_revenues = list(map(lambda movie: revenue_with_year(movie['budget_2013$'], movie['year']),scaled_movies))
internal_consultant_estimated_trace = trace_values(budgets, internal_consultant_estimated_revenues, mode='markers', name = 'internal consultant estimate')

# %%
internal_consultant_estimated_trace['x'][0:10] # [13.0, 45.66, 20.0, 61.0, 40.0, 225.0, 92.0, 12.0, 13.0, 130.0]
internal_consultant_estimated_trace['y'][0:10] # [86.3, 120.726, 94.0, 139.10000000000002, 116.0, 319.5, 173.2, 85.2, 86.3, 215.0]
internal_consultant_estimated_trace['mode'] # 'markers'

# %%
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

from graph import trace_values, m_b_trace, plot
plot([revenues_per_budgets_trace, consultant_estimated_revenues_trace, internal_consultant_estimated_trace], revenues_layout)

# %% [markdown]
# Although the `internal consultant model` isn't a line, it still seems to match our data fairly well.  Let's find out how well.  Even though it is not a line, we can still calculate the RSS for this model.  Write a function called `rss_revenue_with_year` that returns the Residual Sum of Squares associated with the `revenue_with_year` model for the `scaled_movies` dataset.  The `squared_error_revenue_with_year` function can be used to return the squared error of the model associated with just a single movie.

# %%
def squared_error_revenue_with_year(movie):
    pass

def rss_revenue_with_year(movies):
    pass

# %%
rss_revenue_with_year(scaled_movies) # 25364329.23

# %% [markdown]
# The RSS here is $25,364,329.23$ as opposed to the RSS of $23,234,357.68$ from the external consultant's model.  According to RSS, this model isn't as accurate as the previous model. Still, it isn't bad enough to ignore completely.

# %% [markdown]
# ### Our initial regression line, and improving upon it

# %% [markdown]
# Now that we have evaluated the models of an outside consultant and an internal consultant, it's time to see if we can do any better.  Let's go.

# %% [markdown]
# We have our dataset. Let's begin with an initial regression line that sets $b = 0.5$ and $m = 1.79$.

# %%
from linear_equations import build_regression_line
budgets = list(map(lambda movie: movie['budget_2013$'], scaled_movies)) or [1, 2]
domestic_revenues = list(map(lambda movie: movie['domgross_2013$'], scaled_movies)) or [1, 2]

# %%
initial_regression_line = {'b': 0.5, 'm': 1.79}

# %% [markdown]
# Using values for $m$ and $b$ from our initial regression line, we can write `expected_revenue_per_budget` that returns the expected revenue provided a budget.

# %%
def expected_revenue_per_budget(budget):
    pass

# %%
budget = american_hustle['budget_2013$'] # 40.0
expected_revenue_per_budget(budget) # 72.1

# %% [markdown]
# Now this initial regression line was not very sophisticated. We simply drew a line between the points with the lowest and highest $x$ values.
#
# Let's plot our initial regression line along our dataset to get a sense of the accuracy of this first line.

# %%
budgets = list(map(lambda movie: movie['budget_2013$'], scaled_movies))
estimated_revenues = list(map(lambda budget: expected_revenue_per_budget(budget), budgets))
len(estimated_revenues)
initial_regression_trace = trace_values(budgets, estimated_revenues, mode = 'lines', name = 'initial regression trace')

# %%
plot([revenues_per_budgets_trace, initial_regression_trace], revenues_layout)

# %% [markdown]
# By now we should be able to guess the next step: quantify how well this line matches our data.  We'll write a function called `regression_revenue_error` that, provided a movie and an `m` and `b` value of a regression line, returns the difference between our `initial_regression_lines`'s expected revenue and the actual revenue error.

# %%
def regression_revenue_error(m, b, movie):
    pass

# %%
initial_regression_line

# %%
american_hustle = {'binary': 'PASS', 'budget': 40.0, 'budget_2013$': 40.0, 'clean_test': 'ok',
         'code': '2013PASS', 'decade code': 1.0, 'domgross': 148.43, 'domgross_2013$': 148.43, 'imdb': 'tt1800241',
         'intgross': 249.48, 'intgross_2013$': 249.48, 'period code': 1.0, 'test': 'ok-disagree',
         'title': 'American Hustle', 'year': 2013}

regression_revenue_error(initial_regression_line['m'], initial_regression_line['b'], american_hustle)
# 76.33

# %% [markdown]
# Ok, now plot the cost curve from changing values of $m$ from $1.0$ to $1.9$.
#
# > We don't ask you to write a function for calculating the RSS, as you already wrote one in the error library which is available to you, and you can see used here.

# %%
from error import residual_sum_squares
residual_sum_squares(budgets, domestic_revenues, initial_regression_line['m'], initial_regression_line['b'])

# %% [markdown]
# But we do ask you to plot a cost curve from 1.0, to 1.9 using that `residual_sum_squares` function. We start off with a list of values of m from 1.0 to 1.9, assigned to `m_range` below.

# %%
large_m_range = list(range(10, 20))
m_range = list(map(lambda m_value: m_value/10,large_m_range))

# %% [markdown]
# Now we need to calculate a list of RSS values associated with each value in the `m_range`.

# %%
cost_values = list(map(lambda m_value: round(residual_sum_squares(budgets, domestic_revenues, m_value, initial_regression_line['b']), 2),m_range))

# %%
from graph import trace_values
rss_trace = trace_values(x_values=m_range, y_values=cost_values, mode = 'lines')

# %%
rss_trace

# %%
plot([rss_trace])

# %% [markdown]
# Ok, so based on this, it appears that with our $b = 0.5$, the slope of our regression line that produces the lowest error is between $1.3$ and $1.4$. In fact if we replace our initial line value of $m$ with $1.3$, we see that our RSS does in fact decline from our previous value of $24,179,824$.

# %%
residual_sum_squares(budgets, domestic_revenues, 1.3, initial_regression_line['b'])

# %% [markdown]
# ### Changing multiple variables

# %% [markdown]
# Ok, now it's time to move beyond testing the accuracy of the line with changing only a single variable.  We need to play with both variables to find the 'best fit regression line'. As we know, the technique for that is to use gradient descent.
#
# Remember that we derived our gradient formulas by starting with our cost function, and saying the RSS is a function of our $m$ and $b$ variables:

# %% [markdown]
# $$J(m,b) = \sum_{i = 1}^n(y_i - (mx_i + b))^2$$

# %% [markdown]
# From the above formula for our cost curve, we found the gradient descent of the cost function, as that is used to find the incremental changes to decrease RSS. We do this mathematically, by taking the partial derivative with respect to $m$ and $b$.
#
# $$ \frac{\partial J}{\partial b}J(m,b) = -2\sum_{i = 1}^n(y_i - (mx_i + b)) = -2\sum_{i = 1}^n \epsilon_i $$
# $$ \frac{\partial J}{\partial m}J(m,b) = -2\sum_{i = 1}^n x(y_i - (mx_i + b)) = -2\sum_{i = 1}^n x_i*\epsilon_i$$

# %% [markdown]
# Looking at our top function $\frac{\partial J}{\partial m}$, we see that it equals negative 2, multiplied by the sum of the errors for a provided $m$ and $b$ values relative to our dataset.  And luckily for us, we already have a function called `regression_revenue_error` that returns the error at a given point when provided our $m$ and $b$ values.
#
# Recall, that we learned that the factor of 2 can be discarded since it is present in both formulas. Additionally, recall that the error needs to be scaled by the size of the dataset to prevent larger datasets from having larger errors.
#
# $$ \frac{\partial J}{\partial b}J(m,b) = -\frac{1}{n}\sum_{i = 1}^n \epsilon_i $$
# $$ \frac{\partial J}{\partial m}J(m,b) = -\frac{1}{n}\sum_{i = 1}^n x_i*\epsilon_i$$
#
# Our task now is two write a function called `b_gradient` that takes in values of $m$, $b$ and our (scaled) movies, and returns the `b` gradient.

# %%
def b_gradient(m, b, movies):
    pass

# %%
b_gradient(1.79, 0.50, scaled_movies) # 5.37

# %% [markdown]
# Next, write a function called `m_gradient` that returns the `m` gradient for values of $m$, $b$, and a list of movies.

# %%
def m_gradient(m, b, movies):
    pass

# %%
m_gradient(1.79, 0.50, scaled_movies) # 2520.59

# %% [markdown]
# > Notice that the `m_gradient` is significantly larger than the `b_gradient`. This makes sense since the `m_gradient` formula is similar to the `b_gradient` formula, except that its output is also multiplied by the corresponding $x$ value.

# %% [markdown]
# Ok, now we just wrote two functions that tell us how to update the corresponding values of $m$ and $b$.  Our next step is to write a function called `step_gradient` that will use these functions to take the step down along our cost curve.
#
# Remember that with each step we want to move our `current_b` value in the negative direction of calculated `b_gradient`, and want to move our `current_m` value in the negative direction of the calculated `m_gradient`.
#
# `current_m` = `old_m` $ -  \eta(-\frac{1}{n}*\sum_{i=1}^n x_i*\epsilon_i )$
#
# `current_b` =  `old_b` $ - \eta(-\frac{1}{n}*\sum_{i=1}^n \epsilon_i )$
#
# The `step_gradient` function would take as arguments the `b_current`, `m_current`, the list of scaled movies, and a learning rate, and returns a newly calculated `b_current` and `m_current` with a dictionary of keys `b` and `m` that point to the current values.

# %%
def step_gradient(b_current, m_current, movies, learning_rate):
    pass

# %%
initial_regression_line # {'b': 0.5, 'm': 1.79}

# %% [markdown]
# Then let's see how our formula changes over time using gradient descent.

# %%
step_gradient(initial_regression_line['b'], initial_regression_line['m'], scaled_movies, .0001)

# %% [markdown]
# Now write a function that can operate given a set of 100 iterations and start from our `initial_regression_line`.

# %%
# set our initial step with m and b values, and the corresponding error.
def generate_steps(m, b, number_of_steps, movies, learning_rate):
    pass

#     iterations = []
#     for i in range(number_of_steps):
#         iteration = step_gradient(b, m, movies, learning_rate)
#         # {'b': value, 'm': value}
#         b = iteration['b']
#         m = iteration['m']
#         # update values of b and m
#         iterations.append(iteration)
#     return iterations

# %%
iterations = generate_steps(initial_regression_line['m'], initial_regression_line['b'], 100, scaled_movies, .0001) or [{'m': 'uncomment generate_steps method', 'b': 'uncomment generate_steps method '}]

# %% [markdown]
# And we can see how this changes over time.

# %%
def to_line(m, b):
    initial_x = 0
    ending_x = 500
    initial_y = m*initial_x + b
    ending_y = m*ending_x + b
    return {'data': [{'x': [initial_x, ending_x], 'y': [initial_y, ending_y]}]}

frames = list(map(lambda iteration: to_line(iteration['m'], iteration['b']), iterations))

# %%
from plotly.offline import init_notebook_mode, iplot
from IPython.display import display, HTML

init_notebook_mode(connected=True)

budgets = list(map(lambda movie: movie['budget_2013$'], scaled_movies))
domestic_revenues = list(map(lambda movie: movie['domgross_2013$'], scaled_movies))

figure = {'data': [{'x': [0], 'y': [0]}, {'x': budgets, 'y': domestic_revenues, 'mode': 'markers'}],
          'layout': {'title': 'Regression Line',
                     'updatemenus': [{'type': 'buttons',
                                      'buttons': [{'label': 'Play',
                                                   'method': 'animate',
                                                   'args': [None]}]}]
                    },
          'frames': frames}
iplot(figure)

# %% [markdown]
# Finally, let's calculate the RSS associated with our formula as opposed to the other.

# %%
iterations[-1] # {'b': 0.5, 'm': 1.38}

# %%
residual_sum_squares(budgets, domestic_revenues, iterations[-1]['m'], iterations[-1]['b'])

# %% [markdown]
# Using this last iteration, we have an RSS $22052973.85$, better than all previous models - and we have the data, and knowledge to prove it:

# %%
external_consultant_model = rss_consultant(scaled_movies)
internal_consultant_model = rss_revenue_with_year(scaled_movies)
our_regression_model = residual_sum_squares(budgets, domestic_revenues, iterations[-1]['m'], iterations[-1]['b'])

# %%
external_consultant_model # 23234357.68
internal_consultant_model # 25364329.23
our_regression_model      # 22052973.85

# %% [markdown]
# Nice work!
